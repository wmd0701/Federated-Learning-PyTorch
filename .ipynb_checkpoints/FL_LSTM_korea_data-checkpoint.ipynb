# %%
import pandas as pd
import numpy  as np
import scipy.io
import pickle
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import f1_score, accuracy_score
import copy
import math
from tqdm import notebook
import matplotlib.pyplot as plt

# GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# reproducibility
np.random.seed(0)
torch.manual_seed(0)

# tensorboard
# %load_ext tensorboard
# %reload_ext tensorboard
# if running in linux, please replace "rmdir /s /q" with "rm -rf" 
# !rmdir /s /q runs
writer = SummaryWriter()
# Out:
# cuda

# %% [markdown]
# ## Data preprocessing

# %%
# which data to use
use_affectnet = True
use_openface  = True

# read fold_ids.csv
fold_ids_df = pd.read_csv("../fold_ids.csv")

user_ids = fold_ids_df["participant_id"]
uuids    = fold_ids_df["uuid"]
mws      = fold_ids_df["MW"]

all_ids    = []
all_labels = []
all_data   = []

# not using data from all frames 
seq_length = 300               # 10 seconds * 30 FPS
sampling   = 10                # only 30 frames are used out of 300 frames

for user_id, uuid, mw in zip(user_ids, uuids, mws):
    if use_affectnet and not use_openface: # using affectnet features
        affectnet_features = scipy.io.loadmat("../features/affectnet/" + uuid + "_faces.mat")["features"]
        if affectnet_features.shape[0] == seq_length:
            affectnet_features = affectnet_features[range(0, seq_length, sampling)]
            all_ids.append(user_id)
            all_labels.append(1.0 if mw == 'n' else 0.0)
            all_data.append(affectnet_features)
        
    elif use_openface and not use_affectnet: # using openface features
        openface_pd        = pd.read_csv("../features/Openface_features/" + uuid + ".csv")
        openface_features  = openface_pd.drop(openface_pd.columns[:5], axis=1)      # drop first five columns as they are not needed
        if openface_features.shape[0] == seq_length:
            openface_features = openface_features.iloc[range(0, seq_length, sampling)]
            all_ids.append(user_id)
            all_labels.append(1.0 if mw == 'n' else 0.0)
            all_data.append(openface_features)
    
    else: # using both features
        affectnet_features = scipy.io.loadmat("../features/affectnet/" + uuid + "_faces.mat")["features"]
        openface_pd        = pd.read_csv("../features/Openface_features/" + uuid + ".csv")
        openface_features  = openface_pd.drop(openface_pd.columns[:5], axis=1)      # drop first five columns as they are not needed
        if affectnet_features.shape[0] == openface_features.shape[0]:               # drop samples that have different number of rows in affectnet features and in openface features
            combined_features = np.concatenate((affectnet_features, openface_features), axis = 1)
            combined_features = combined_features[range(0, seq_length, sampling)]
            all_ids.append(user_id)
            all_labels.append(1.0 if mw == 'n' else 0.0)
            all_data.append(combined_features)
            
# list to torch tensors
all_labels = torch.tensor(all_labels)
all_data   = torch.tensor(np.array(all_data)).float()       # (df -> np array -> torch tensor) faster than (df -> torch tensor)

# data normalization
data_mean = all_data.mean(axis=(0,1))
data_std  = all_data.std (axis=(0,1))
all_data  = (all_data - data_mean) / (data_std + 1e-6)

# %%
print(all_data.shape)
print(all_labels.unique(return_counts=True))
# Out:
# torch.Size([1209, 30, 2757])
# (tensor([0., 1.]), tensor([1006,  203]))

# %% [markdown]
# ### Help functions

# %%
# average model parameters
def weighted_avg_params(params, weights = None):
    if weights == None:
        weights = [1.0] * len(params)
        
    params_avg = copy.deepcopy(params[0])
    for key in params_avg.keys():
        params_avg[key] *= weights[0]
        for i in range(1, len(params)):
            params_avg[key] += params[i][key] * weights[i]
        params_avg[key] = torch.div(params_avg[key], sum(weights))
    return params_avg

# get weights for each class
def get_weight_dict(labels):
    unique_labels, unique_counts = labels.unique(return_counts=True)
    weight_dict = {}
    sum_counts = sum(unique_counts)
    for label, counts in zip(unique_labels, unique_counts):
        weight_dict[label.item()] = sum_counts / counts
    sum_weights = sum(weight_dict.values())
    
    # normalize weights 
    for _, weight in weight_dict.items():
        weight /= sum_weights
    return weight_dict

# for a vector of labels, return a vector of same length of weights
def get_weight_vector(weight_dict, labels):
    weight_vec = [weight_dict[label.item()] for label in labels]
    weight_vec = torch.tensor(weight_vec, device = labels.device)
    return weight_vec

def weighted_avg(values, weights):
    sum_values = 0
    for v, w in zip(values, weights):
        sum_values += v *w
    return sum_values / sum(weights)

# %% [markdown]
# ### Dataset class

# %%
class DatasetMW(torch.utils.data.Dataset):
    def __init__(self, labels, weight_dict, data, batch_size):
        self.labels      = labels
        self.data        = data
        self.weight_dict = weight_dict
        # normalize again, not necessary
        for _, weight in self.weight_dict.items():
            weight *= batch_size
        self.weights = get_weight_vector(self.weight_dict, labels)
        
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        label   = self.labels [idx]
        weight  = self.weights[idx]
        feature = self.data   [idx]     
        return label, weight, feature

# %% [markdown]
# ## LSTM model

# %%
# LSTM model 
class LSTM(torch.nn.Module):
    def __init__(self, 
                 i_size  = all_data[0].shape[1] , # input dimension, for this project it should be 709 (openface features) or 2048 (affectnet features) or 2757 (both)
                 h_size  = 128                  , # hidden state dimension
                 n_layer = 1                    , # number of hidden layers
                 bi_dir  = True                 , # bi-directional LSTM or not
                 dropout = 0.5                  , # dropout rate for LSTM and MLP
                 batch_size = 4                 ,
                 using_hn   = True              , # use hidden state or output of LSTM as input for mlp
                ):
        super(LSTM, self).__init__()
        
        D = 2 if bi_dir else 1
        
        self.h0 = torch.nn.Parameter(torch.randn(D * n_layer, batch_size, h_size), requires_grad=True)
        self.c0 = torch.nn.Parameter(torch.randn(D * n_layer, batch_size, h_size), requires_grad=True)
        
        self.lstm = torch.nn.LSTM(input_size = i_size, hidden_size = h_size, num_layers = n_layer, bidirectional = bi_dir, dropout = dropout, batch_first = True)
        self.mlp  = MLP(D * n_layer * h_size) if using_hn else MLP(D * h_size)
        
        self.using_hn = using_hn
    
    def forward(self, x):
        output, (hn, cn) = self.lstm(x, (self.h0, self.c0))
        
        # using hidden state of LSTM as input to MLP
        if self.using_hn:
            hn = hn.permute(1, 0, 2).flatten(1)
            hn = self.mlp(hn)
            return hn
        # using output of LSTM as input to MLP
        else:
            output = output[:, -1, :]          # many-to-one LSTM
            output = self.mlp(output)
            return output
    
# MLP model
class MLP(torch.nn.Module):
    def __init__(self, input_size):
        super(MLP, self).__init__()
        self.layer0  = torch.nn.Linear(input_size, 16)
        self.layer1  = torch.nn.Linear(16, 1)
        self.relu    = torch.nn.ReLU()
        self.sigmoid = torch.nn.Sigmoid()
        self.dropout = torch.nn.Dropout(p = 0.5)
        
    def forward(self, x):
        x = self.layer0(x) ; x = self.dropout(x) ; x = self.relu(x)
        x = self.layer1(x) ; x = self.sigmoid(x)
        return x

# %% [markdown]
# ## Client

# %% [markdown]
# ### Client class

# %%
# client is an object, which contains its own dataset, dataloader, local model copy (for simplification, only local parameters) and training loop fucntion
class Client(object):
    def __init__(self, client_id, client_labels, client_data, weight_dict, batch_size, train_test_split, global_model, learning_rate, l2_regular, client_epoch, reuse_optimizer = True):
        super(Client, self).__init__()
        self.client_id     = client_id
        self.client_labels = client_labels
        self.client_data   = client_data
        self.weight_dict   = weight_dict
        self.batch_size    = batch_size
        self.client_epoch  = client_epoch
        self.learning_rate = learning_rate
        self.l2_regular    = l2_regular
        self.optim_state   = None
        self.reuse_optimizer   = reuse_optimizer
        self.train_epoch_count = 0
        self.test_epoch_count  = 0
        
        # dataset and data loader
        dataset = DatasetMW(self.client_labels, self.weight_dict, self.client_data, self.batch_size)

        # train test split
        self.client_split = 0 < train_test_split < 1
        if self.client_split:
            train_test_split = max(train_test_split, 1 - train_test_split)
            train_size = int(train_test_split * len(dataset))
            test_size  = len(dataset) - train_size
            self.train_dataset, self.test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
        else:
            self.train_dataset = dataset
            self.test_dataset  = None

        # dataloader
        self.train_loader = torch.utils.data.DataLoader(self.train_dataset, batch_size = batch_size, shuffle = True, drop_last=True)
        self.test_loader  = torch.utils.data.DataLoader(self.test_dataset , batch_size = batch_size, shuffle = True, drop_last=True)
        
        # client model
        if global_model is None:
            self.client_model = LSTM(batch_size = batch_size)
        else:
            self.client_model = copy.deepcopy(global_model)
        
        # recording loss, accuracy, and f1 score during training and test
        self.train_loss = []
        self.train_accu = []
        self.train_f1   = []
        self.test_loss  = []
        self.test_accu  = []
        self.test_f1    = []
        
    ############################### local train ###################################
    def local_train(self):
        """ local training
        
        @ return      : avg training loss per epoch, avg training accuracy per epoch, avg training f1 score per epoch
        """
        
        # model to GPU
        self.client_model.to(device)
        self.client_model.train()
        
        # optimizer, and load previous optimizer state
        optimizer = torch.optim.Adam(self.client_model.parameters(), lr = self.learning_rate, weight_decay = self.l2_regular)
        if self.reuse_optimizer and self.optim_state is not None:
            optimizer.load_state_dict(self.optim_state)
        
        for epoch in range(self.client_epoch):
            sum_batch_loss = 0
            sum_batch_len  = 0
            epoch_labels   = []
            epoch_predicts = []
            
            for batch_id, (labels, weights, sequences) in enumerate(self.train_loader):
                sum_batch_len += len(labels)
                optimizer.zero_grad()
                
                labels    = labels   .to(device)
                weights   = weights  .to(device)
                sequences = sequences.to(device)
                predicts  = self.client_model(sequences).view(-1)
                
                loss = F.binary_cross_entropy(predicts, labels, reduction = 'mean', weight = weights)
                loss.backward()
                # torch.nn.utils.clip_grad_norm_(self.client_model.parameters(), 1.0)          # clip gradient
                optimizer.step()
                
                sum_batch_loss += loss.item() * len(labels)
                predicts = predicts.round()
                epoch_labels  .append(labels)
                epoch_predicts.append(predicts)
            
            # calculate loss, accuracy, and f1 score
            epoch_label   = torch.concatenate(epoch_labels  ).detach().to('cpu').numpy()
            epoch_predict = torch.concatenate(epoch_predicts).detach().to('cpu').numpy()
            epoch_loss    = sum_batch_loss / sum_batch_len
            epoch_accu    = accuracy_score(epoch_label, epoch_predict)
            epoch_f1      = f1_score      (epoch_label, epoch_predict, zero_division = 0)         
            
            # add to tensorboard
            writer.add_scalar(self.client_id + '/train/loss', epoch_loss, self.train_epoch_count)
            writer.add_scalar(self.client_id + '/train/accu', epoch_accu, self.train_epoch_count)
            writer.add_scalar(self.client_id + '/train/f1'  , epoch_f1  , self.train_epoch_count)
            writer.flush()
            self.train_epoch_count += 1
        
            self.train_loss.append(epoch_loss)
            self.train_accu.append(epoch_accu)
            self.train_f1  .append(epoch_f1  )
            
        # model to CPU and save optimizer state
        self.client_model.to('cpu')
        if self.reuse_optimizer:
            self.optim_state = optimizer.state_dict()
            
        avg_epoch_loss = sum(self.train_loss[-self.client_epoch:]) / self.client_epoch
        avg_epoch_accu = sum(self.train_accu[-self.client_epoch:]) / self.client_epoch
        avg_epoch_f1   = sum(self.train_f1  [-self.client_epoch:]) / self.client_epoch

        return avg_epoch_loss, avg_epoch_accu, avg_epoch_f1
    
    ############################### local test ###################################
    def local_test(self):
        """ local test
        
        @ return      : avg test loss, avg test accuracy, avg test f1 score
        """
        
        assert(self.client_split)
        
        self.client_model.to(device)
        self.client_model.eval()
        sum_batch_loss = 0
        sum_batch_len  = 0
        epoch_labels   = []
        epoch_predicts = []
        
        with torch.no_grad():
            for batch_id, (labels, weights, sequences) in enumerate(self.test_loader):
                sum_batch_len += len(labels)
                labels    = labels   .to(device)
                weights   = weights  .to(device)
                sequences = sequences.to(device)
                predicts  = self.client_model(sequences).view(-1)

                loss = F.binary_cross_entropy(predicts, labels, reduction = 'mean', weight = weights)
                sum_batch_loss += loss.item() * len(labels)

                predicts = predicts.round()
                epoch_labels  .append(labels)
                epoch_predicts.append(predicts)

        epoch_label   = torch.concatenate(epoch_labels  ).detach().to('cpu').numpy()
        epoch_predict = torch.concatenate(epoch_predicts).detach().to('cpu').numpy()
        epoch_loss    = sum_batch_loss / sum_batch_len
        epoch_accu    = accuracy_score(epoch_label, epoch_predict)
        epoch_f1      = f1_score      (epoch_label, epoch_predict, zero_division = 0)         

        self.test_loss.append(epoch_loss)
        self.test_accu.append(epoch_accu)
        self.test_f1  .append(epoch_f1)

        writer.add_scalar(self.client_id + '/test/loss', epoch_loss, self.test_epoch_count)
        writer.add_scalar(self.client_id + '/test/accu', epoch_accu, self.test_epoch_count)
        writer.add_scalar(self.client_id + '/test/f1'  , epoch_f1  , self.test_epoch_count)
        writer.flush()
        self.test_epoch_count += 1
        
        self.client_model.to('cpu')
        
        return epoch_loss, epoch_accu, epoch_f1

# %% [markdown]
# ### get_clients function

# %%
def get_clients(batch_size   , 
                global_model , 
                learning_rate, 
                l2_regular   , 
                client_epoch ,
                reuse_optimizer ,
                train_test_split, 
                all_ids    = all_ids, 
                all_labels = all_labels, 
                all_data   = all_data,
                global_preprocessing = False):

    clients = []
    
    # global data imbalance and global normalization
    if global_preprocessing:
        data_mean   = all_data.mean(axis=(0,1))
        data_std    = all_data.std (axis=(0,1))
        all_data    = (all_data - data_mean) / (data_std + 1e-6)
        weight_dict = get_weight_dict(all_labels)
    
    
    # data entries for each client
    unique_ids, unique_counts = np.unique(all_ids, return_counts=True)
    global_counts = 0
    for client_id, client_counts in zip(unique_ids, unique_counts):
        
        client_labels = all_labels[global_counts : global_counts + client_counts]
        client_data   = all_data  [global_counts : global_counts + client_counts]
        
        # local data imbalance and local normalization
        if not global_preprocessing:
            client_mean = client_data.mean(axis=(0,1))
            client_std  = client_data.std (axis=(0,1))
            client_data = (client_data - client_mean) / (client_std + 1e-6)
            weight_dict = get_weight_dict(client_labels)
            
        client = Client(client_id     = client_id     , 
                        client_labels = client_labels , 
                        client_data   = client_data   ,
                        weight_dict   = weight_dict   ,
                        batch_size    = batch_size    , 
                        global_model  = global_model  , 
                        learning_rate = learning_rate , 
                        l2_regular    = l2_regular    , 
                        client_epoch  = client_epoch  ,
                        reuse_optimizer  = reuse_optimizer  ,
                        train_test_split = train_test_split ,
                       )
                
        clients.append(client)
        global_counts += client_counts
            
    return clients

# %% [markdown]
# ## Global update

# %%
def federated_learning(global_epoch     = 500   ,
                       client_epoch     = 10    ,
                       update_C         = 0.1   ,
                       batch_size       = 4     ,
                       learning_rate    = 1e-5  ,
                       l2_regular       = 1e-1  ,
                       reuse_optimizer  = True  ,
                       train_test_split = 0.8   ,
                       global_init      = True ,
                       global_preprocessing = False,
                       known_client_data_size = True,
                      ):
    """ simulation of federated learning
    
    @ global_epoch    : number of rounds for global update
    @ client_epoch    : number of rounds for local  update (parameter E in paper)
    @ update_C        : proportion of clients that are updated in each global round (parameter C in paper)
    @ batch_size      : local batch size
    @ learning_rate   : local learning rate
    @ l2_regular      : local l2 regularization
    @ reuse_optimizer : whether the state of local optimizer is re-used 
    @ train_test_split: local train test split, any value outside (0, 1) means not doing split
    
    @ global_init           : whether all local models have the same initilization
    @ global_preprocessing  : whether data is normalized globally or locally
    @ known_client_data_size: whether the global center knows how much data each client has
    
    """
    
    # global model
    global_model = LSTM(batch_size = batch_size)
    
    # determine how many clients are updated per global round
    num_client        = len(np.unique(all_ids, return_counts=True)[0])
    num_update_client = min(max(math.ceil(update_C * num_client), 1), num_client) # number of clients to update per round
    print("total number of clients:", num_client, " number of clients to be updated in each global round:", num_update_client)
    print()
    
    clients = get_clients(batch_size       = batch_size    , 
                          learning_rate    = learning_rate , 
                          l2_regular       = l2_regular    , 
                          client_epoch     = client_epoch  ,
                          reuse_optimizer  = reuse_optimizer ,
                          train_test_split = train_test_split,
                          global_model     = global_model if global_init else None,
                          global_preprocessing = global_preprocessing
                         )
    
    # global test dataset and data loader
    if 0 < train_test_split < 1:
        test_datasets = [c.test_dataset for c in clients]
        global_test_dataset = torch.utils.data.ConcatDataset(test_datasets)
        global_test_loader  = torch.utils.data.DataLoader(global_test_dataset, batch_size = batch_size, shuffle = True, drop_last=True)
        
    # global update loop
    for epoch in notebook.tqdm(range(global_epoch)):
        client_ids     = np.random.choice(num_client, num_update_client, replace=False)
        client_weights = []
        client_params  = []
        client_train_losses  = []
        client_train_accus   = []
        client_train_f1s     = []
        client_test_losses   = []
        client_test_accus    = []
        client_test_f1s      = []
        
        # local update
        for client_id in client_ids:
            client = clients[client_id]
            client_weights.append(len(client.client_data) if known_client_data_size else 1.0)
            
            # local train
            loss, accu, f1 = client.local_train()
            client_params.append(client.client_model.state_dict())
            client_train_losses.append(loss)
            client_train_accus .append(accu)
            client_train_f1s   .append(f1)
            
            # local test
            loss, accu, f1 = client.local_test()
            client_test_losses.append(loss)
            client_test_accus .append(accu)
            client_test_f1s   .append(f1)
        
        # print
        avg_client_train_loss = weighted_avg(values = client_train_losses, weights = client_weights)
        avg_client_train_accu = weighted_avg(values = client_train_accus , weights = client_weights)
        avg_client_train_f1   = weighted_avg(values = client_train_f1s   , weights = client_weights)
        avg_client_test_loss  = weighted_avg(values = client_test_losses , weights = client_weights)
        avg_client_test_accu  = weighted_avg(values = client_test_accus  , weights = client_weights)
        avg_client_test_f1    = weighted_avg(values = client_test_f1s    , weights = client_weights)
        print("global epoch: {:02d}".format(epoch), " updating clients:", client_ids)
        print("avg client train loss: {:.4f}".format(avg_client_train_loss), " avg client train accu: {:.4f}".format(avg_client_train_accu), " avg client train f1: {:.4f}".format(avg_client_train_f1))
        print("avg client test  loss: {:.4f}".format(avg_client_test_loss ), " avg client test  accu: {:.4f}".format(avg_client_test_accu ), " avg client test  f1: {:.4f}".format(avg_client_test_f1 ))
        
        # add to tensorboard
        writer.add_scalar('global/train/avg_loss', avg_client_train_loss, epoch)
        writer.add_scalar('global/train/avg_accu', avg_client_train_accu, epoch)
        writer.add_scalar('global/train/avg_f1'  , avg_client_train_f1  , epoch)
        writer.add_scalar('global/test/avg_loss' , avg_client_test_loss , epoch)
        writer.add_scalar('global/test/avg_accu' , avg_client_test_accu , epoch)
        writer.add_scalar('global/test/avg_f1'   , avg_client_test_f1   , epoch)
        writer.flush()
        
        # global model aggregation
        client_params .append(global_model.state_dict())
        client_weights.append(len(all_data) if known_client_data_size else 1.0)
        new_global_params = weighted_avg_params(params = client_params, weights = client_weights)
        
        # update global model
        global_model.load_state_dict(new_global_params)
        
        # update local models
        for client in clients:
            client.client_model.load_state_dict(new_global_params)
            
        # global test
        global_model.to(device)
        global_model.eval()
        sum_batch_loss = 0
        sum_batch_len  = 0
        global_test_labels   = []
        global_test_predicts = []
        
        with torch.no_grad():
            for batch_id, (labels, weights, sequences) in enumerate(global_test_loader):
                sum_batch_len += len(labels)
                labels    = labels   .to(device)
                weights   = weights  .to(device)
                sequences = sequences.to(device)
                predicts  = global_model(sequences).view(-1)

                loss = F.binary_cross_entropy(predicts, labels, reduction = 'mean', weight = weights)
                sum_batch_loss += loss.item() * len(labels)

                predicts = predicts.round()
                global_test_labels  .append(labels)
                global_test_predicts.append(predicts)

        global_test_label   = torch.concatenate(global_test_labels  ).detach().to('cpu').numpy()
        global_test_predict = torch.concatenate(global_test_predicts).detach().to('cpu').numpy()
        global_test_loss    = sum_batch_loss / sum_batch_len
        global_test_accu    = accuracy_score(global_test_label, global_test_predict)
        global_test_f1      = f1_score      (global_test_label, global_test_predict, zero_division = 0)
        
        # print
        print("global test loss: {:.4f}".format(global_test_loss), " global test accu: {:.4f}".format(global_test_accu), " global test f1: {:.4f}".format(global_test_f1))
        print("global test predicts:", np.unique(global_test_predict, return_counts=True), "global test truth:", np.unique(global_test_label, return_counts=True))
        
        # add to tensorboard
        writer.add_scalar('global/test/global_loss', avg_client_train_loss, epoch)
        writer.add_scalar('global/test/global_accu', avg_client_train_accu, epoch)
        writer.add_scalar('global/test/global_f1'  , avg_client_train_f1  , epoch)
        
        print("======================================================================================================================================================================================================")
        
        global_model.to('cpu')

# %% [markdown]
# ## Run and plots

# %%
# %reload_ext tensorboard
# !rmdir /s /q runs
writer = SummaryWriter()
# %tensorboard --logdir runs

federated_learning(update_C     = 0.1,
                   client_epoch = 50, 
                   global_epoch = 1000,
                   
                   learning_rate   = 1e-5,
                   l2_regular      = 1e-1,
                   reuse_optimizer = True,
                   
                   global_init = True,
                   global_preprocessing = False,
                  )
# Out:
# Reusing TensorBoard on port 6006 (pid 11308), started 4 days, 11:14:35 ago. (Use '!kill 11308' to kill it.)
#       <iframe id="tensorboard-frame-e95b68abc93a5cca" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-e95b68abc93a5cca");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
# C:\Software\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:67: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# total number of clients: 15  number of clients to be updated in each global round: 2
#   0%|          | 0/1000 [00:00<?, ?it/s]
# global epoch: 00  updating clients: [11  3]
# avg client train loss: 0.5549  avg client train accu: 0.4799  avg client train f1: 0.2976
# avg client test  loss: 0.5418  avg client test  accu: 0.1829  avg client test  f1: 0.1481
# global test loss: 0.8473  global test accu: 0.3320  global test f1: 0.2275
# global test predicts: (array([0., 1.], dtype=float32), array([ 70, 174], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 01  updating clients: [11  3]
# avg client train loss: 0.5198  avg client train accu: 0.5735  avg client train f1: 0.3645
# avg client test  loss: 0.5167  avg client test  accu: 0.2523  avg client test  f1: 0.1481
# global test loss: 0.8560  global test accu: 0.3238  global test f1: 0.2254
# global test predicts: (array([0., 1.], dtype=float32), array([ 68, 176], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 02  updating clients: [7 6]
# avg client train loss: 1.1455  avg client train accu: 0.6304  avg client train f1: 0.0423
# avg client test  loss: 1.1085  avg client test  accu: 0.6219  avg client test  f1: 0.0000
# global test loss: 0.8369  global test accu: 0.6230  global test f1: 0.1786
# global test predicts: (array([0., 1.], dtype=float32), array([168,  76], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 03  updating clients: [ 0 10]
# avg client train loss: 1.0347  avg client train accu: 0.7620  avg client train f1: 0.6308
# avg client test  loss: 1.1231  avg client test  accu: 0.5296  avg client test  f1: 0.1228
# global test loss: 0.8411  global test accu: 0.6066  global test f1: 0.1429
# global test predicts: (array([0., 1.], dtype=float32), array([168,  76], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 04  updating clients: [2 9]
# avg client train loss: 0.3605  avg client train accu: 0.8177  avg client train f1: 0.4216
# avg client test  loss: 0.4412  avg client test  accu: 0.7511  avg client test  f1: 0.1404
# global test loss: 0.8459  global test accu: 0.6803  global test f1: 0.1875
# global test predicts: (array([0., 1.], dtype=float32), array([185,  59], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 05  updating clients: [14  3]
# avg client train loss: 0.9902  avg client train accu: 0.8546  avg client train f1: 0.7856
# avg client test  loss: 1.0372  avg client test  accu: 0.5672  avg client test  f1: 0.2748
# global test loss: 0.8500  global test accu: 0.5615  global test f1: 0.2190
# global test predicts: (array([0., 1.], dtype=float32), array([144, 100], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 06  updating clients: [1 5]
# avg client train loss: 0.7043  avg client train accu: 0.8287  avg client train f1: 0.6740
# avg client test  loss: 0.7170  avg client test  accu: 0.6346  avg client test  f1: 0.0000
# global test loss: 0.8314  global test accu: 0.6107  global test f1: 0.2520
# global test predicts: (array([0., 1.], dtype=float32), array([153,  91], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 07  updating clients: [12 13]
# avg client train loss: 0.8194  avg client train accu: 0.8545  avg client train f1: 0.7890
# avg client test  loss: 0.7840  avg client test  accu: 0.8582  avg client test  f1: 0.7007
# global test loss: 0.8455  global test accu: 0.5656  global test f1: 0.2740
# global test predicts: (array([0., 1.], dtype=float32), array([135, 109], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 08  updating clients: [13  0]
# avg client train loss: 0.6878  avg client train accu: 0.9087  avg client train f1: 0.8536
# avg client test  loss: 1.0977  avg client test  accu: 0.7514  avg client test  f1: 0.4306
# global test loss: 0.8673  global test accu: 0.5369  global test f1: 0.2207
# global test predicts: (array([0., 1.], dtype=float32), array([136, 108], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 09  updating clients: [3 6]
# avg client train loss: 0.4140  avg client train accu: 0.8226  avg client train f1: 0.4843
# avg client test  loss: 0.6857  avg client test  accu: 0.6036  avg client test  f1: 0.0872
# global test loss: 0.8463  global test accu: 0.5984  global test f1: 0.2794
# global test predicts: (array([0., 1.], dtype=float32), array([145,  99], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 10  updating clients: [4 6]
# avg client train loss: 0.3222  avg client train accu: 0.8828  avg client train f1: 0.5662
# avg client test  loss: 0.4999  avg client test  accu: 0.8132  avg client test  f1: 0.3059
# global test loss: 0.8242  global test accu: 0.6680  global test f1: 0.2957
# global test predicts: (array([0., 1.], dtype=float32), array([166,  78], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 11  updating clients: [9 4]
# avg client train loss: 0.2813  avg client train accu: 0.9435  avg client train f1: 0.7493
# avg client test  loss: 0.5961  avg client test  accu: 0.7818  avg client test  f1: 0.5226
# global test loss: 0.8387  global test accu: 0.6967  global test f1: 0.2745
# global test predicts: (array([0., 1.], dtype=float32), array([179,  65], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 12  updating clients: [3 6]
# avg client train loss: 0.3900  avg client train accu: 0.8733  avg client train f1: 0.5440
# avg client test  loss: 0.6653  avg client test  accu: 0.6752  avg client test  f1: 0.1585
# global test loss: 0.8530  global test accu: 0.6230  global test f1: 0.2812
# global test predicts: (array([0., 1.], dtype=float32), array([152,  92], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 13  updating clients: [6 9]
# avg client train loss: 0.1028  avg client train accu: 0.9290  avg client train f1: 0.5663
# avg client test  loss: 0.2318  avg client test  accu: 0.9062  avg client test  f1: 0.2500
# global test loss: 0.8413  global test accu: 0.7295  global test f1: 0.2979
# global test predicts: (array([0., 1.], dtype=float32), array([187,  57], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 14  updating clients: [5 0]
# avg client train loss: 0.6331  avg client train accu: 0.8453  avg client train f1: 0.7001
# avg client test  loss: 1.1844  avg client test  accu: 0.6261  avg client test  f1: 0.1092
# global test loss: 0.8406  global test accu: 0.6393  global test f1: 0.1852
# global test predicts: (array([0., 1.], dtype=float32), array([173,  71], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 15  updating clients: [10  9]
# avg client train loss: 0.4563  avg client train accu: 0.8957  avg client train f1: 0.7653
# avg client test  loss: 1.0826  avg client test  accu: 0.5312  avg client test  f1: 0.0000
# global test loss: 0.8659  global test accu: 0.6721  global test f1: 0.1304
# global test predicts: (array([0., 1.], dtype=float32), array([189,  55], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 16  updating clients: [6 3]
# avg client train loss: 0.3754  avg client train accu: 0.8785  avg client train f1: 0.5676
# avg client test  loss: 0.7112  avg client test  accu: 0.6741  avg client test  f1: 0.0872
# global test loss: 0.8582  global test accu: 0.6066  global test f1: 0.2381
# global test predicts: (array([0., 1.], dtype=float32), array([154,  90], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 17  updating clients: [2 4]
# avg client train loss: 0.3736  avg client train accu: 0.8927  avg client train f1: 0.7555
# avg client test  loss: 0.6703  avg client test  accu: 0.6573  avg client test  f1: 0.3035
# global test loss: 0.8555  global test accu: 0.6557  global test f1: 0.3000
# global test predicts: (array([0., 1.], dtype=float32), array([161,  83], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 18  updating clients: [1 2]
# avg client train loss: 0.3664  avg client train accu: 0.9248  avg client train f1: 0.8135
# avg client test  loss: 0.5907  avg client test  accu: 0.7121  avg client test  f1: 0.0000
# global test loss: 0.8456  global test accu: 0.6762  global test f1: 0.2178
# global test predicts: (array([0., 1.], dtype=float32), array([179,  65], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 19  updating clients: [ 4 13]
# avg client train loss: 0.3539  avg client train accu: 0.9693  avg client train f1: 0.9171
# avg client test  loss: 0.7309  avg client test  accu: 0.7855  avg client test  f1: 0.5395
# global test loss: 0.8529  global test accu: 0.6311  global test f1: 0.2373
# global test predicts: (array([0., 1.], dtype=float32), array([163,  81], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 20  updating clients: [5 9]
# avg client train loss: 0.2182  avg client train accu: 0.9388  avg client train f1: 0.7960
# avg client test  loss: 0.7616  avg client test  accu: 0.7500  avg client test  f1: 0.1429
# global test loss: 0.8419  global test accu: 0.6639  global test f1: 0.2115
# global test predicts: (array([0., 1.], dtype=float32), array([176,  68], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 21  updating clients: [10 13]
# avg client train loss: 0.5525  avg client train accu: 0.9119  avg client train f1: 0.8332
# avg client test  loss: 1.2322  avg client test  accu: 0.6057  avg client test  f1: 0.1046
# global test loss: 0.8558  global test accu: 0.6516  global test f1: 0.1905
# global test predicts: (array([0., 1.], dtype=float32), array([175,  69], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 22  updating clients: [14  7]
# avg client train loss: 0.7618  avg client train accu: 0.8922  avg client train f1: 0.3502
# avg client test  loss: 1.1129  avg client test  accu: 0.7948  avg client test  f1: 0.1368
# global test loss: 0.8833  global test accu: 0.7992  global test f1: 0.1967
# global test predicts: (array([0., 1.], dtype=float32), array([219,  25], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 23  updating clients: [8 3]
# avg client train loss: 0.3449  avg client train accu: 0.9240  avg client train f1: 0.6696
# avg client test  loss: 0.9219  avg client test  accu: 0.7060  avg client test  f1: 0.0988
# global test loss: 0.8478  global test accu: 0.6680  global test f1: 0.2286
# global test predicts: (array([0., 1.], dtype=float32), array([174,  70], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([209,  35], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 24  updating clients: [ 3 12]
# avg client train loss: 0.5397  avg client train accu: 0.9299  avg client train f1: 0.8975
# avg client test  loss: 1.1372  avg client test  accu: 0.6686  avg client test  f1: 0.5398
# global test loss: 0.9026  global test accu: 0.6967  global test f1: 0.2449
# global test predicts: (array([0., 1.], dtype=float32), array([182,  62], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 25  updating clients: [10  2]
# avg client train loss: 0.4121  avg client train accu: 0.9063  avg client train f1: 0.7903
# avg client test  loss: 1.2422  avg client test  accu: 0.5296  avg client test  f1: 0.0000
# global test loss: 0.8642  global test accu: 0.7172  global test f1: 0.2581
# global test predicts: (array([0., 1.], dtype=float32), array([187,  57], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 26  updating clients: [9 3]
# avg client train loss: 0.2371  avg client train accu: 0.9666  avg client train f1: 0.8869
# avg client test  loss: 0.9181  avg client test  accu: 0.7821  avg client test  f1: 0.1090
# global test loss: 0.8851  global test accu: 0.6844  global test f1: 0.2222
# global test predicts: (array([0., 1.], dtype=float32), array([182,  62], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 27  updating clients: [13  5]
# avg client train loss: 0.3028  avg client train accu: 0.9428  avg client train f1: 0.8664
# avg client test  loss: 0.9121  avg client test  accu: 0.8208  avg client test  f1: 0.2832
# global test loss: 0.8384  global test accu: 0.6066  global test f1: 0.2727
# global test predicts: (array([0., 1.], dtype=float32), array([149,  95], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 28  updating clients: [13  1]
# avg client train loss: 0.2754  avg client train accu: 0.9648  avg client train f1: 0.9393
# avg client test  loss: 0.4586  avg client test  accu: 0.8976  avg client test  f1: 0.3611
# global test loss: 0.8517  global test accu: 0.5943  global test f1: 0.2080
# global test predicts: (array([0., 1.], dtype=float32), array([155,  89], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 29  updating clients: [3 6]
# avg client train loss: 0.2491  avg client train accu: 0.9066  avg client train f1: 0.6415
# avg client test  loss: 0.8038  avg client test  accu: 0.7468  avg client test  f1: 0.1090
# global test loss: 0.8698  global test accu: 0.6434  global test f1: 0.2564
# global test predicts: (array([0., 1.], dtype=float32), array([164,  80], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 30  updating clients: [7 2]
# avg client train loss: 0.4084  avg client train accu: 0.9509  avg client train f1: 0.4157
# avg client test  loss: 0.6002  avg client test  accu: 0.8308  avg client test  f1: 0.0000
# global test loss: 0.9151  global test accu: 0.7746  global test f1: 0.2029
# global test predicts: (array([0., 1.], dtype=float32), array([212,  32], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 31  updating clients: [13  9]
# avg client train loss: 0.1456  avg client train accu: 0.9872  avg client train f1: 0.9292
# avg client test  loss: 0.5921  avg client test  accu: 0.8568  avg client test  f1: 0.2832
# global test loss: 0.8325  global test accu: 0.7541  global test f1: 0.2105
# global test predicts: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 32  updating clients: [9 3]
# avg client train loss: 0.2685  avg client train accu: 0.9714  avg client train f1: 0.9426
# avg client test  loss: 1.0025  avg client test  accu: 0.6752  avg client test  f1: 0.0969
# global test loss: 0.8894  global test accu: 0.7090  global test f1: 0.2022
# global test predicts: (array([0., 1.], dtype=float32), array([192,  52], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 33  updating clients: [13 12]
# avg client train loss: 0.3986  avg client train accu: 0.9589  avg client train f1: 0.9377
# avg client test  loss: 0.5457  avg client test  accu: 0.8933  avg client test  f1: 0.4486
# global test loss: 0.9365  global test accu: 0.6926  global test f1: 0.2991
# global test predicts: (array([0., 1.], dtype=float32), array([174,  70], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 34  updating clients: [ 6 13]
# avg client train loss: 0.0880  avg client train accu: 0.9506  avg client train f1: 0.6852
# avg client test  loss: 0.1465  avg client test  accu: 0.8927  avg client test  f1: 0.0000
# global test loss: 0.8319  global test accu: 0.6393  global test f1: 0.2281
# global test predicts: (array([0., 1.], dtype=float32), array([166,  78], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 35  updating clients: [12  0]
# avg client train loss: 0.5336  avg client train accu: 0.9153  avg client train f1: 0.8673
# avg client test  loss: 1.5101  avg client test  accu: 0.7478  avg client test  f1: 0.5516
# global test loss: 0.9599  global test accu: 0.6844  global test f1: 0.2222
# global test predicts: (array([0., 1.], dtype=float32), array([182,  62], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 36  updating clients: [ 3 10]
# avg client train loss: 0.5869  avg client train accu: 0.8923  avg client train f1: 0.8160
# avg client test  loss: 1.9042  avg client test  accu: 0.5000  avg client test  f1: 0.1090
# global test loss: 0.9328  global test accu: 0.6189  global test f1: 0.2677
# global test predicts: (array([0., 1.], dtype=float32), array([154,  90], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 37  updating clients: [7 8]
# avg client train loss: 0.2820  avg client train accu: 0.9507  avg client train f1: 0.2956
# avg client test  loss: 0.4422  avg client test  accu: 0.9323  avg client test  f1: 0.0000
# global test loss: 0.9114  global test accu: 0.7705  global test f1: 0.1765
# global test predicts: (array([0., 1.], dtype=float32), array([213,  31], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 38  updating clients: [7 9]
# avg client train loss: 0.2133  avg client train accu: 0.9879  avg client train f1: 0.4491
# avg client test  loss: 0.4758  avg client test  accu: 0.9313  avg client test  f1: 0.0000
# global test loss: 0.9793  global test accu: 0.7910  global test f1: 0.0000
# global test predicts: (array([0., 1.], dtype=float32), array([230,  14], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 39  updating clients: [ 8 14]
# avg client train loss: 0.3491  avg client train accu: 0.9105  avg client train f1: 0.6900
# avg client test  loss: 0.9053  avg client test  accu: 0.7169  avg client test  f1: 0.0000
# global test loss: 0.8634  global test accu: 0.7459  global test f1: 0.1622
# global test predicts: (array([0., 1.], dtype=float32), array([206,  38], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 40  updating clients: [ 2 10]
# avg client train loss: 0.4410  avg client train accu: 0.9025  avg client train f1: 0.7463
# avg client test  loss: 1.2702  avg client test  accu: 0.6217  avg client test  f1: 0.0000
# global test loss: 0.8602  global test accu: 0.7213  global test f1: 0.0811
# global test predicts: (array([0., 1.], dtype=float32), array([206,  38], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 41  updating clients: [1 9]
# avg client train loss: 0.2122  avg client train accu: 0.9566  avg client train f1: 0.8457
# avg client test  loss: 1.0464  avg client test  accu: 0.7788  avg client test  f1: 0.0000
# global test loss: 0.9115  global test accu: 0.6885  global test f1: 0.1364
# global test predicts: (array([0., 1.], dtype=float32), array([192,  52], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 42  updating clients: [3 5]
# avg client train loss: 0.4293  avg client train accu: 0.9147  avg client train f1: 0.8259
# avg client test  loss: 1.2466  avg client test  accu: 0.6400  avg client test  f1: 0.0969
# global test loss: 0.9692  global test accu: 0.6189  global test f1: 0.2314
# global test predicts: (array([0., 1.], dtype=float32), array([160,  84], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 43  updating clients: [14 10]
# avg client train loss: 0.5019  avg client train accu: 0.9234  avg client train f1: 0.8728
# avg client test  loss: 1.5127  avg client test  accu: 0.5307  avg client test  f1: 0.1243
# global test loss: 0.9133  global test accu: 0.6311  global test f1: 0.1818
# global test predicts: (array([0., 1.], dtype=float32), array([171,  73], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 44  updating clients: [2 8]
# avg client train loss: 0.1372  avg client train accu: 0.9457  avg client train f1: 0.7734
# avg client test  loss: 0.4904  avg client test  accu: 0.8438  avg client test  f1: 0.0000
# global test loss: 0.8712  global test accu: 0.7213  global test f1: 0.1707
# global test predicts: (array([0., 1.], dtype=float32), array([198,  46], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 45  updating clients: [ 8 10]
# avg client train loss: 0.2641  avg client train accu: 0.9699  avg client train f1: 0.8988
# avg client test  loss: 0.9767  avg client test  accu: 0.5910  avg client test  f1: 0.0000
# global test loss: 0.9042  global test accu: 0.6885  global test f1: 0.1163
# global test predicts: (array([0., 1.], dtype=float32), array([194,  50], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 46  updating clients: [1 8]
# avg client train loss: 0.1811  avg client train accu: 0.9764  avg client train f1: 0.9135
# avg client test  loss: 0.5994  avg client test  accu: 0.7879  avg client test  f1: 0.0000
# global test loss: 0.9343  global test accu: 0.6680  global test f1: 0.1474
# global test predicts: (array([0., 1.], dtype=float32), array([185,  59], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 47  updating clients: [ 1 10]
# avg client train loss: 0.3870  avg client train accu: 0.9658  avg client train f1: 0.9340
# avg client test  loss: 2.1695  avg client test  accu: 0.5192  avg client test  f1: 0.0000
# global test loss: 1.0038  global test accu: 0.6475  global test f1: 0.1400
# global test predicts: (array([0., 1.], dtype=float32), array([181,  63], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 48  updating clients: [1 5]
# avg client train loss: 0.2972  avg client train accu: 0.9411  avg client train f1: 0.8664
# avg client test  loss: 1.0788  avg client test  accu: 0.7500  avg client test  f1: 0.0000
# global test loss: 0.9397  global test accu: 0.5738  global test f1: 0.1475
# global test predicts: (array([0., 1.], dtype=float32), array([158,  86], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 49  updating clients: [5 7]
# avg client train loss: 0.2779  avg client train accu: 0.9814  avg client train f1: 0.5099
# avg client test  loss: 0.8366  avg client test  accu: 0.8969  avg client test  f1: 0.0000
# global test loss: 1.0539  global test accu: 0.7459  global test f1: 0.0882
# global test predicts: (array([0., 1.], dtype=float32), array([212,  32], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 50  updating clients: [13 11]
# avg client train loss: 0.1229  avg client train accu: 0.9142  avg client train f1: 0.5119
# avg client test  loss: 0.2660  avg client test  accu: 0.7861  avg client test  f1: 0.2167
# global test loss: 0.8317  global test accu: 0.6967  global test f1: 0.1778
# global test predicts: (array([0., 1.], dtype=float32), array([190,  54], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 51  updating clients: [4 3]
# avg client train loss: 0.3923  avg client train accu: 0.9466  avg client train f1: 0.9135
# avg client test  loss: 1.5455  avg client test  accu: 0.5321  avg client test  f1: 0.3939
# global test loss: 0.9078  global test accu: 0.6721  global test f1: 0.2727
# global test predicts: (array([0., 1.], dtype=float32), array([171,  73], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 52  updating clients: [0 3]
# avg client train loss: 0.4774  avg client train accu: 0.9060  avg client train f1: 0.8472
# avg client test  loss: 2.4073  avg client test  accu: 0.5324  avg client test  f1: 0.1389
# global test loss: 1.0770  global test accu: 0.6230  global test f1: 0.1930
# global test predicts: (array([0., 1.], dtype=float32), array([166,  78], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 53  updating clients: [ 3 13]
# avg client train loss: 0.2423  avg client train accu: 0.9696  avg client train f1: 0.9506
# avg client test  loss: 1.4878  avg client test  accu: 0.6629  avg client test  f1: 0.3722
# global test loss: 1.0191  global test accu: 0.5779  global test f1: 0.2137
# global test predicts: (array([0., 1.], dtype=float32), array([150,  94], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 54  updating clients: [5 4]
# avg client train loss: 0.2115  avg client train accu: 0.9749  avg client train f1: 0.9418
# avg client test  loss: 0.9631  avg client test  accu: 0.7189  avg client test  f1: 0.2712
# global test loss: 0.8819  global test accu: 0.6639  global test f1: 0.2407
# global test predicts: (array([0., 1.], dtype=float32), array([172,  72], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 55  updating clients: [4 6]
# avg client train loss: 0.0961  avg client train accu: 0.9703  avg client train f1: 0.7974
# avg client test  loss: 0.6545  avg client test  accu: 0.7511  avg client test  f1: 0.2295
# global test loss: 0.8565  global test accu: 0.7008  global test f1: 0.2626
# global test predicts: (array([0., 1.], dtype=float32), array([182,  62], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 56  updating clients: [3 5]
# avg client train loss: 0.3150  avg client train accu: 0.9433  avg client train f1: 0.8864
# avg client test  loss: 1.7045  avg client test  accu: 0.6058  avg client test  f1: 0.2701
# global test loss: 0.9586  global test accu: 0.6803  global test f1: 0.2500
# global test predicts: (array([0., 1.], dtype=float32), array([177,  67], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 57  updating clients: [11 12]
# avg client train loss: 0.2347  avg client train accu: 0.9154  avg client train f1: 0.5894
# avg client test  loss: 0.3151  avg client test  accu: 0.8441  avg client test  f1: 0.3294
# global test loss: 0.8826  global test accu: 0.6885  global test f1: 0.2400
# global test predicts: (array([0., 1.], dtype=float32), array([181,  63], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 58  updating clients: [10 13]
# avg client train loss: 0.3800  avg client train accu: 0.9394  avg client train f1: 0.8855
# avg client test  loss: 1.3809  avg client test  accu: 0.5697  avg client test  f1: 0.2124
# global test loss: 0.8447  global test accu: 0.6148  global test f1: 0.2769
# global test predicts: (array([0., 1.], dtype=float32), array([151,  93], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 59  updating clients: [2 7]
# avg client train loss: 0.2719  avg client train accu: 0.9633  avg client train f1: 0.4449
# avg client test  loss: 0.4234  avg client test  accu: 0.8646  avg client test  f1: 0.0000
# global test loss: 0.9151  global test accu: 0.8033  global test f1: 0.1724
# global test predicts: (array([0., 1.], dtype=float32), array([223,  21], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 60  updating clients: [11  0]
# avg client train loss: 0.2533  avg client train accu: 0.9328  avg client train f1: 0.6352
# avg client test  loss: 1.1591  avg client test  accu: 0.7500  avg client test  f1: 0.1250
# global test loss: 0.8653  global test accu: 0.8033  global test f1: 0.1429
# global test predicts: (array([0., 1.], dtype=float32), array([225,  19], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 61  updating clients: [6 2]
# avg client train loss: 0.1013  avg client train accu: 0.9631  avg client train f1: 0.7624
# avg client test  loss: 0.2495  avg client test  accu: 0.8454  avg client test  f1: 0.0000
# global test loss: 0.8017  global test accu: 0.7828  global test f1: 0.2933
# global test predicts: (array([0., 1.], dtype=float32), array([206,  38], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 62  updating clients: [6 9]
# avg client train loss: 0.0623  avg client train accu: 0.9676  avg client train f1: 0.7670
# avg client test  loss: 0.1062  avg client test  accu: 0.9688  avg client test  f1: 0.5000
# global test loss: 0.8198  global test accu: 0.7664  global test f1: 0.1972
# global test predicts: (array([0., 1.], dtype=float32), array([210,  34], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 63  updating clients: [0 7]
# avg client train loss: 0.4987  avg client train accu: 0.9417  avg client train f1: 0.4426
# avg client test  loss: 1.4397  avg client test  accu: 0.7631  avg client test  f1: 0.1203
# global test loss: 0.9906  global test accu: 0.8115  global test f1: 0.1154
# global test predicts: (array([0., 1.], dtype=float32), array([229,  15], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 64  updating clients: [14  7]
# avg client train loss: 0.4354  avg client train accu: 0.9329  avg client train f1: 0.4230
# avg client test  loss: 1.0494  avg client test  accu: 0.7264  avg client test  f1: 0.1094
# global test loss: 1.0354  global test accu: 0.7951  global test f1: 0.1379
# global test predicts: (array([0., 1.], dtype=float32), array([223,  21], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 65  updating clients: [11  3]
# avg client train loss: 0.2141  avg client train accu: 0.9444  avg client train f1: 0.6107
# avg client test  loss: 1.0359  avg client test  accu: 0.6713  avg client test  f1: 0.0988
# global test loss: 0.9174  global test accu: 0.6680  global test f1: 0.1980
# global test predicts: (array([0., 1.], dtype=float32), array([180,  64], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 66  updating clients: [7 8]
# avg client train loss: 0.1749  avg client train accu: 0.9516  avg client train f1: 0.2882
# avg client test  loss: 0.3921  avg client test  accu: 0.9323  avg client test  f1: 0.0000
# global test loss: 0.9475  global test accu: 0.7623  global test f1: 0.0938
# global test predicts: (array([0., 1.], dtype=float32), array([216,  28], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 67  updating clients: [4 1]
# avg client train loss: 0.3933  avg client train accu: 0.9412  avg client train f1: 0.8508
# avg client test  loss: 1.2491  avg client test  accu: 0.7117  avg client test  f1: 0.3770
# global test loss: 0.9381  global test accu: 0.7090  global test f1: 0.2022
# global test predicts: (array([0., 1.], dtype=float32), array([191,  53], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 68  updating clients: [12 13]
# avg client train loss: 0.4031  avg client train accu: 0.9531  avg client train f1: 0.9268
# avg client test  loss: 0.7047  avg client test  accu: 0.8933  avg client test  f1: 0.7414
# global test loss: 0.8086  global test accu: 0.6598  global test f1: 0.2655
# global test predicts: (array([0., 1.], dtype=float32), array([168,  76], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 69  updating clients: [11  9]
# avg client train loss: 0.0531  avg client train accu: 0.9469  avg client train f1: 0.6641
# avg client test  loss: 0.1184  avg client test  accu: 0.9079  avg client test  f1: 0.5087
# global test loss: 0.8302  global test accu: 0.7541  global test f1: 0.1429
# global test predicts: (array([0., 1.], dtype=float32), array([211,  33], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 70  updating clients: [7 9]
# avg client train loss: 0.1910  avg client train accu: 0.9984  avg client train f1: 0.5378
# avg client test  loss: 0.4079  avg client test  accu: 0.9313  avg client test  f1: 0.0000
# ...
# avg client test  loss: 1.5997  avg client test  accu: 0.5592  avg client test  f1: 0.0000
# global test loss: 0.8184  global test accu: 0.7582  global test f1: 0.1918
# global test predicts: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 977  updating clients: [ 8 12]
# avg client train loss: 0.2251  avg client train accu: 0.9638  avg client train f1: 0.8804
# avg client test  loss: 0.5462  avg client test  accu: 0.9066  avg client test  f1: 0.3952
# global test loss: 0.8727  global test accu: 0.7746  global test f1: 0.2466
# global test predicts: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 978  updating clients: [4 3]
# avg client train loss: 0.2867  avg client train accu: 0.9729  avg client train f1: 0.9571
# avg client test  loss: 1.4899  avg client test  accu: 0.6388  avg client test  f1: 0.4182
# global test loss: 0.9188  global test accu: 0.7131  global test f1: 0.2708
# global test predicts: (array([0., 1.], dtype=float32), array([185,  59], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 979  updating clients: [ 4 14]
# avg client train loss: 0.2608  avg client train accu: 0.9650  avg client train f1: 0.9403
# avg client test  loss: 1.4095  avg client test  accu: 0.6875  avg client test  f1: 0.3750
# global test loss: 0.8951  global test accu: 0.7090  global test f1: 0.2970
# global test predicts: (array([0., 1.], dtype=float32), array([180,  64], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 980  updating clients: [ 8 12]
# avg client train loss: 0.1789  avg client train accu: 0.9765  avg client train f1: 0.9000
# avg client test  loss: 0.5128  avg client test  accu: 0.8750  avg client test  f1: 0.3952
# global test loss: 0.9210  global test accu: 0.7500  global test f1: 0.2078
# global test predicts: (array([0., 1.], dtype=float32), array([203,  41], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 981  updating clients: [1 7]
# avg client train loss: 0.2541  avg client train accu: 0.9781  avg client train f1: 0.3938
# avg client test  loss: 1.0395  avg client test  accu: 0.8917  avg client test  f1: 0.0000
# global test loss: 1.1648  global test accu: 0.7910  global test f1: 0.1053
# global test predicts: (array([0., 1.], dtype=float32), array([224,  20], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 982  updating clients: [14  4]
# avg client train loss: 0.2986  avg client train accu: 0.9594  avg client train f1: 0.9177
# avg client test  loss: 1.7294  avg client test  accu: 0.6562  avg client test  f1: 0.3472
# global test loss: 0.9459  global test accu: 0.8033  global test f1: 0.2941
# global test predicts: (array([0., 1.], dtype=float32), array([213,  31], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 983  updating clients: [ 7 11]
# avg client train loss: 0.0843  avg client train accu: 0.9793  avg client train f1: 0.3430
# avg client test  loss: 0.1687  avg client test  accu: 0.8985  avg client test  f1: 0.0000
# global test loss: 0.9542  global test accu: 0.8033  global test f1: 0.2258
# global test predicts: (array([0., 1.], dtype=float32), array([218,  26], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 984  updating clients: [13  3]
# avg client train loss: 0.3412  avg client train accu: 0.9666  avg client train f1: 0.9401
# avg client test  loss: 1.6005  avg client test  accu: 0.6610  avg client test  f1: 0.4394
# global test loss: 0.9037  global test accu: 0.6434  global test f1: 0.2162
# global test predicts: (array([0., 1.], dtype=float32), array([170,  74], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 985  updating clients: [13  6]
# avg client train loss: 0.0725  avg client train accu: 0.9744  avg client train f1: 0.8191
# avg client test  loss: 0.3821  avg client test  accu: 0.9286  avg client test  f1: 0.2832
# global test loss: 0.8124  global test accu: 0.6926  global test f1: 0.2424
# global test predicts: (array([0., 1.], dtype=float32), array([182,  62], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 986  updating clients: [3 2]
# avg client train loss: 0.2738  avg client train accu: 0.9571  avg client train f1: 0.8895
# avg client test  loss: 1.0311  avg client test  accu: 0.6736  avg client test  f1: 0.1111
# global test loss: 0.8800  global test accu: 0.7090  global test f1: 0.2680
# global test predicts: (array([0., 1.], dtype=float32), array([183,  61], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 987  updating clients: [13  5]
# avg client train loss: 0.1851  avg client train accu: 0.9698  avg client train f1: 0.9345
# avg client test  loss: 0.9959  avg client test  accu: 0.7849  avg client test  f1: 0.4476
# global test loss: 0.8707  global test accu: 0.6270  global test f1: 0.2602
# global test predicts: (array([0., 1.], dtype=float32), array([158,  86], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 988  updating clients: [4 3]
# avg client train loss: 0.2499  avg client train accu: 0.9791  avg client train f1: 0.9659
# avg client test  loss: 1.7248  avg client test  accu: 0.5687  avg client test  f1: 0.3470
# global test loss: 0.9143  global test accu: 0.6844  global test f1: 0.2804
# global test predicts: (array([0., 1.], dtype=float32), array([174,  70], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 989  updating clients: [1 9]
# avg client train loss: 0.1624  avg client train accu: 0.9587  avg client train f1: 0.8782
# avg client test  loss: 0.5608  avg client test  accu: 0.8654  avg client test  f1: 0.4103
# global test loss: 0.9226  global test accu: 0.7459  global test f1: 0.1842
# global test predicts: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 990  updating clients: [12  4]
# avg client train loss: 0.2704  avg client train accu: 0.9769  avg client train f1: 0.9651
# avg client test  loss: 0.8282  avg client test  accu: 0.7790  avg client test  f1: 0.6180
# global test loss: 0.9232  global test accu: 0.7295  global test f1: 0.3125
# global test predicts: (array([0., 1.], dtype=float32), array([185,  59], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 991  updating clients: [2 0]
# avg client train loss: 0.3367  avg client train accu: 0.9232  avg client train f1: 0.8405
# avg client test  loss: 1.6270  avg client test  accu: 0.7188  avg client test  f1: 0.1250
# global test loss: 0.9810  global test accu: 0.7582  global test f1: 0.2532
# global test predicts: (array([0., 1.], dtype=float32), array([202,  42], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 992  updating clients: [ 8 12]
# avg client train loss: 0.1858  avg client train accu: 0.9584  avg client train f1: 0.7987
# avg client test  loss: 0.5525  avg client test  accu: 0.8750  avg client test  f1: 0.3952
# global test loss: 0.9553  global test accu: 0.7664  global test f1: 0.1739
# global test predicts: (array([0., 1.], dtype=float32), array([212,  32], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 993  updating clients: [5 0]
# avg client train loss: 0.3145  avg client train accu: 0.9380  avg client train f1: 0.8811
# avg client test  loss: 1.3903  avg client test  accu: 0.7522  avg client test  f1: 0.3772
# global test loss: 0.9561  global test accu: 0.7295  global test f1: 0.2143
# global test predicts: (array([0., 1.], dtype=float32), array([197,  47], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 994  updating clients: [7 9]
# avg client train loss: 0.1388  avg client train accu: 0.9906  avg client train f1: 0.5028
# avg client test  loss: 0.2519  avg client test  accu: 1.0000  avg client test  f1: 0.5500
# global test loss: 1.1334  global test accu: 0.7992  global test f1: 0.0392
# global test predicts: (array([0., 1.], dtype=float32), array([230,  14], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 995  updating clients: [7 9]
# avg client train loss: 0.1041  avg client train accu: 0.9984  avg client train f1: 0.5293
# avg client test  loss: 0.4197  avg client test  accu: 0.9313  avg client test  f1: 0.0000
# global test loss: 1.1477  global test accu: 0.7951  global test f1: 0.0000
# global test predicts: (array([0., 1.], dtype=float32), array([231,  13], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 996  updating clients: [12  0]
# avg client train loss: 0.3902  avg client train accu: 0.9650  avg client train f1: 0.9396
# avg client test  loss: 1.4448  avg client test  accu: 0.7485  avg client test  f1: 0.5217
# global test loss: 1.0432  global test accu: 0.7664  global test f1: 0.1739
# global test predicts: (array([0., 1.], dtype=float32), array([211,  33], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 997  updating clients: [1 4]
# avg client train loss: 0.2490  avg client train accu: 0.9799  avg client train f1: 0.9516
# avg client test  loss: 1.5720  avg client test  accu: 0.7016  avg client test  f1: 0.3063
# global test loss: 1.0067  global test accu: 0.7377  global test f1: 0.2381
# global test predicts: (array([0., 1.], dtype=float32), array([197,  47], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 998  updating clients: [10  4]
# avg client train loss: 0.2813  avg client train accu: 0.9691  avg client train f1: 0.9417
# avg client test  loss: 1.6818  avg client test  accu: 0.6239  avg client test  f1: 0.2841
# global test loss: 0.9382  global test accu: 0.6844  global test f1: 0.1348
# global test predicts: (array([0., 1.], dtype=float32), array([192,  52], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([207,  37], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 999  updating clients: [ 9 13]
# avg client train loss: 0.1010  avg client train accu: 0.9844  avg client train f1: 0.9401
# avg client test  loss: 0.5795  avg client test  accu: 0.8932  avg client test  f1: 0.5959
# global test loss: 0.8800  global test accu: 0.7295  global test f1: 0.1538
# global test predicts: (array([0., 1.], dtype=float32), array([202,  42], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([208,  36], dtype=int64))
# ======================================================================================================================================================================================================
