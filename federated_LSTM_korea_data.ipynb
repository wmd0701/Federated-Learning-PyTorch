# %%
import pandas as pd
import numpy  as np
import scipy.io
import pickle
import torch
import torch.nn.functional as F
from torch.utils.tensorboard import SummaryWriter
from sklearn.metrics import f1_score, accuracy_score
import copy
import math
from tqdm import notebook
import matplotlib.pyplot as plt

# GPU
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print(device)

# reproducibility
np.random.seed(0)
torch.manual_seed(0)

# tensorboard
# %load_ext tensorboard
# %reload_ext tensorboard
# if running in linux, please replace "rmdir /s /q" with "rm -rf" 
# !rmdir /s /q runs
writer = SummaryWriter()
# Out:
# cuda

# %% [markdown]
# ## Data preprocessing

# %%
# which data to use
use_affectnet = True
use_openface  = True

# read fold_ids.csv
fold_ids_df = pd.read_csv("../fold_ids.csv")

user_ids = fold_ids_df["participant_id"]
uuids    = fold_ids_df["uuid"]
mws      = fold_ids_df["MW"]

all_ids    = []
all_labels = []
all_data   = []

# not using data from all frames 
seq_length = 300               # 10 seconds * 30 FPS
sampling   = 10                # only 30 frames are used out of 300 frames

for user_id, uuid, mw in zip(user_ids, uuids, mws):
    if use_affectnet and not use_openface: # using affectnet features
        affectnet_features = scipy.io.loadmat("../features/affectnet/" + uuid + "_faces.mat")["features"]
        if affectnet_features.shape[0] == seq_length:
            affectnet_features = affectnet_features[range(0, seq_length, sampling)]
            all_ids.append(user_id)
            all_labels.append(1.0 if mw == 'n' else 0.0)
            all_data.append(affectnet_features)
        
    elif use_openface and not use_affectnet: # using openface features
        openface_pd        = pd.read_csv("../features/Openface_features/" + uuid + ".csv")
        openface_features  = openface_pd.drop(openface_pd.columns[:5], axis=1)      # drop first five columns as they are not needed
        if openface_features.shape[0] == seq_length:
            openface_features = openface_features.iloc[range(0, seq_length, sampling)]
            all_ids.append(user_id)
            all_labels.append(1.0 if mw == 'n' else 0.0)
            all_data.append(openface_features)
    
    else: # using both features
        affectnet_features = scipy.io.loadmat("../features/affectnet/" + uuid + "_faces.mat")["features"]
        openface_pd        = pd.read_csv("../features/Openface_features/" + uuid + ".csv")
        openface_features  = openface_pd.drop(openface_pd.columns[:5], axis=1)      # drop first five columns as they are not needed
        if affectnet_features.shape[0] == openface_features.shape[0]:               # drop samples that have different number of rows in affectnet features and in openface features
            combined_features = np.concatenate((affectnet_features, openface_features), axis = 1)
            combined_features = combined_features[range(0, seq_length, sampling)]
            all_ids.append(user_id)
            all_labels.append(1.0 if mw == 'n' else 0.0)
            all_data.append(combined_features)
            
# list to torch tensors
all_labels = torch.tensor(all_labels)
all_data   = torch.tensor(np.array(all_data)).float()       # (df -> np array -> torch tensor) faster than (df -> torch tensor)

# data normalization
data_mean = all_data.mean(axis=(0,1))
data_std  = all_data.std (axis=(0,1))
all_data  = (all_data - data_mean) / (data_std + 1e-6)

# some prints
print(all_data.shape)
print(all_labels.unique(return_counts=True))
# Out:
# torch.Size([1209, 30, 2757])
# (tensor([0., 1.]), tensor([1006,  203]))

# %% [markdown]
# ### Help functions

# %%
# average model parameters
def weighted_avg_params(params, weights = None):
    if weights == None:
        weights = [1.0] * len(params)
        
    params_avg = copy.deepcopy(params[0])
    for key in params_avg.keys():
        params_avg[key] *= weights[0]
        for i in range(1, len(params)):
            params_avg[key] += params[i][key] * weights[i]
        params_avg[key] = torch.div(params_avg[key], sum(weights))
    return params_avg

# get weights for each class
def get_weight_dict(labels):
    unique_labels, unique_counts = labels.unique(return_counts=True)
    weight_dict = {}
    sum_counts = sum(unique_counts)
    for label, counts in zip(unique_labels, unique_counts):
        weight_dict[label.item()] = sum_counts / counts
    sum_weights = sum(weight_dict.values())
    
    # normalize weights 
    for _, weight in weight_dict.items():
        weight /= sum_weights
    return weight_dict

# for a vector of labels, return a vector of same length of weights
def get_weight_vector(weight_dict, labels):
    weight_vec = [weight_dict[label.item()] for label in labels]
    weight_vec = torch.tensor(weight_vec, device = labels.device)
    return weight_vec

def weighted_avg(values, weights):
    sum_values = 0
    for v, w in zip(values, weights):
        sum_values += v *w
    return sum_values / sum(weights)

# %% [markdown]
# ### Dataset class

# %%
class DatasetMW(torch.utils.data.Dataset):
    def __init__(self, labels, weight_dict, data, batch_size):
        self.labels      = labels
        self.data        = data
        self.weight_dict = weight_dict
        # normalize again, not necessary
        for _, weight in self.weight_dict.items():
            weight *= batch_size
        self.weights = get_weight_vector(self.weight_dict, labels)
        
    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        label   = self.labels [idx]
        weight  = self.weights[idx]
        feature = self.data   [idx]     
        return label, weight, feature

# %% [markdown]
# ## LSTM model

# %%
# LSTM model 
class LSTM(torch.nn.Module):
    def __init__(self, 
                 i_size  = all_data[0].shape[1] , # input dimension, for this project it should be 709 (openface features) or 2048 (affectnet features) or 2757 (both)
                 h_size  = 128                  , # hidden state dimension
                 n_layer = 1                    , # number of hidden layers
                 bi_dir  = True                 , # bi-directional LSTM or not
                 dropout = 0.5                  , # dropout rate for LSTM and MLP
                 batch_size = 4                 ,
                 using_hn   = True              , # use hidden state or output of LSTM as input for mlp
                ):
        super(LSTM, self).__init__()
        
        D = 2 if bi_dir else 1
        
        self.h0 = torch.nn.Parameter(torch.randn(D * n_layer, batch_size, h_size), requires_grad=True)
        self.c0 = torch.nn.Parameter(torch.randn(D * n_layer, batch_size, h_size), requires_grad=True)
        
        self.lstm = torch.nn.LSTM(input_size = i_size, hidden_size = h_size, num_layers = n_layer, bidirectional = bi_dir, dropout = dropout, batch_first = True)
        self.mlp  = MLP(D * n_layer * h_size) if using_hn else MLP(D * h_size)
        
        self.using_hn = using_hn
    
    def forward(self, x):
        output, (hn, cn) = self.lstm(x, (self.h0, self.c0))
        
        # using hidden state of LSTM as input to MLP
        if self.using_hn:
            hn = hn.permute(1, 0, 2).flatten(1)
            hn = self.mlp(hn)
            return hn
        # using output of LSTM as input to MLP
        else:
            output = output[:, -1, :]          # many-to-one LSTM
            output = self.mlp(output)
            return output
    
# MLP model
class MLP(torch.nn.Module):
    def __init__(self, input_size):
        super(MLP, self).__init__()
        self.layer0  = torch.nn.Linear(input_size, 16)
        self.layer1  = torch.nn.Linear(16, 1)
        self.relu    = torch.nn.ReLU()
        self.sigmoid = torch.nn.Sigmoid()
        self.dropout = torch.nn.Dropout(p = 0.5)
        
    def forward(self, x):
        x = self.layer0(x) ; x = self.dropout(x) ; x = self.relu(x)
        x = self.layer1(x) ; x = self.sigmoid(x)
        return x

# %% [markdown]
# ## Client

# %% [markdown]
# ### Client class

# %%
# client is an object, which contains its own dataset, dataloader, local model copy (for simplification, only local parameters) and training loop fucntion
class Client(object):
    def __init__(self, client_id, client_labels, client_data, weight_dict, batch_size, train_test_split, global_model, learning_rate, l2_regular, client_epoch, reuse_optimizer = True):
        super(Client, self).__init__()
        self.client_id     = client_id
        self.client_labels = client_labels
        self.client_data   = client_data
        self.weight_dict   = weight_dict
        self.batch_size    = batch_size
        self.client_epoch  = client_epoch
        self.learning_rate = learning_rate
        self.l2_regular    = l2_regular
        self.optim_state   = None
        self.reuse_optimizer   = reuse_optimizer
        self.train_epoch_count = 0
        self.test_epoch_count  = 0
        
        # dataset and data loader
        dataset = DatasetMW(self.client_labels, self.weight_dict, self.client_data, self.batch_size)

        # train test split
        self.client_split = 0 < train_test_split < 1
        if self.client_split:
            train_test_split = max(train_test_split, 1 - train_test_split)
            train_size = int(train_test_split * len(dataset))
            test_size  = len(dataset) - train_size
            self.train_dataset, self.test_dataset = torch.utils.data.random_split(dataset, [train_size, test_size])
        else:
            self.train_dataset = dataset
            self.test_dataset  = None

        # dataloader
        self.train_loader = torch.utils.data.DataLoader(self.train_dataset, batch_size = batch_size, shuffle = True, drop_last=True)
        self.test_loader  = torch.utils.data.DataLoader(self.test_dataset , batch_size = batch_size, shuffle = True, drop_last=True)
        
        # client model
        if global_model is None:
            self.client_model = LSTM(batch_size = batch_size)
        else:
            self.client_model = copy.deepcopy(global_model)
        
        # recording loss, accuracy, and f1 score during training and test
        self.train_loss = []
        self.train_accu = []
        self.train_f1   = []
        self.test_loss  = []
        self.test_accu  = []
        self.test_f1    = []
        
    ############################### local train ###################################
    def local_train(self):
        """ local training
        
        @ return      : avg training loss per epoch, avg training accuracy per epoch, avg training f1 score per epoch
        """
        
        # model to GPU
        self.client_model.to(device)
        self.client_model.train()
        
        # optimizer, and load previous optimizer state
        optimizer = torch.optim.Adam(self.client_model.parameters(), lr = self.learning_rate, weight_decay = self.l2_regular)
        if self.reuse_optimizer and self.optim_state is not None:
            optimizer.load_state_dict(self.optim_state)
        
        for epoch in range(self.client_epoch):
            sum_batch_loss = 0
            sum_batch_len  = 0
            epoch_labels   = []
            epoch_predicts = []
            
            for batch_id, (labels, weights, sequences) in enumerate(self.train_loader):
                sum_batch_len += len(labels)
                optimizer.zero_grad()
                
                labels    = labels   .to(device)
                weights   = weights  .to(device)
                sequences = sequences.to(device)
                predicts  = self.client_model(sequences).view(-1)
                
                loss = F.binary_cross_entropy(predicts, labels, reduction = 'mean', weight = weights)
                loss.backward()
                # torch.nn.utils.clip_grad_norm_(self.client_model.parameters(), 1.0)          # clip gradient
                optimizer.step()
                
                sum_batch_loss += loss.item() * len(labels)
                predicts = predicts.round()
                epoch_labels  .append(labels)
                epoch_predicts.append(predicts)
            
            # calculate loss, accuracy, and f1 score
            epoch_label   = torch.concatenate(epoch_labels  ).detach().to('cpu').numpy()
            epoch_predict = torch.concatenate(epoch_predicts).detach().to('cpu').numpy()
            epoch_loss    = sum_batch_loss / sum_batch_len
            epoch_accu    = accuracy_score(epoch_label, epoch_predict)
            epoch_f1      = f1_score      (epoch_label, epoch_predict, zero_division = 0)         
            
            # add to tensorboard
            writer.add_scalar(self.client_id + '/train/loss', epoch_loss, self.train_epoch_count)
            writer.add_scalar(self.client_id + '/train/accu', epoch_accu, self.train_epoch_count)
            writer.add_scalar(self.client_id + '/train/f1'  , epoch_f1  , self.train_epoch_count)
            writer.flush()
            self.train_epoch_count += 1
        
            self.train_loss.append(epoch_loss)
            self.train_accu.append(epoch_accu)
            self.train_f1  .append(epoch_f1  )
            
        # model to CPU and save optimizer state
        self.client_model.to('cpu')
        if self.reuse_optimizer:
            self.optim_state = optimizer.state_dict()
            
        avg_epoch_loss = sum(self.train_loss[-self.client_epoch:]) / self.client_epoch
        avg_epoch_accu = sum(self.train_accu[-self.client_epoch:]) / self.client_epoch
        avg_epoch_f1   = sum(self.train_f1  [-self.client_epoch:]) / self.client_epoch

        return avg_epoch_loss, avg_epoch_accu, avg_epoch_f1
    
    ############################### local test ###################################
    def local_test(self):
        """ local test
        
        @ return      : avg test loss, avg test accuracy, avg test f1 score
        """
        
        assert(self.client_split)
        
        self.client_model.to(device)
        self.client_model.eval()
        sum_batch_loss = 0
        sum_batch_len  = 0
        epoch_labels   = []
        epoch_predicts = []
        
        with torch.no_grad():
            for batch_id, (labels, weights, sequences) in enumerate(self.test_loader):
                sum_batch_len += len(labels)
                labels    = labels   .to(device)
                weights   = weights  .to(device)
                sequences = sequences.to(device)
                predicts  = self.client_model(sequences).view(-1)

                loss = F.binary_cross_entropy(predicts, labels, reduction = 'mean', weight = weights)
                sum_batch_loss += loss.item() * len(labels)

                predicts = predicts.round()
                epoch_labels  .append(labels)
                epoch_predicts.append(predicts)

        epoch_label   = torch.concatenate(epoch_labels  ).detach().to('cpu').numpy()
        epoch_predict = torch.concatenate(epoch_predicts).detach().to('cpu').numpy()
        epoch_loss    = sum_batch_loss / sum_batch_len
        epoch_accu    = accuracy_score(epoch_label, epoch_predict)
        epoch_f1      = f1_score      (epoch_label, epoch_predict, zero_division = 0)         

        self.test_loss.append(epoch_loss)
        self.test_accu.append(epoch_accu)
        self.test_f1  .append(epoch_f1)

        writer.add_scalar(self.client_id + '/test/loss', epoch_loss, self.test_epoch_count)
        writer.add_scalar(self.client_id + '/test/accu', epoch_accu, self.test_epoch_count)
        writer.add_scalar(self.client_id + '/test/f1'  , epoch_f1  , self.test_epoch_count)
        writer.flush()
        self.test_epoch_count += 1
        
        self.client_model.to('cpu')
        
        return epoch_loss, epoch_accu, epoch_f1

# %% [markdown]
# ### get_clients function

# %%
def get_clients(batch_size   , 
                global_model , 
                learning_rate, 
                l2_regular   , 
                client_epoch ,
                reuse_optimizer ,
                train_test_split, 
                all_ids    = all_ids, 
                all_labels = all_labels, 
                all_data   = all_data,
                global_preprocessing = False):

    clients = []
    
    # global data imbalance and global normalization
    if global_preprocessing:
        data_mean   = all_data.mean(axis=(0,1))
        data_std    = all_data.std (axis=(0,1))
        all_data    = (all_data - data_mean) / (data_std + 1e-6)
        weight_dict = get_weight_dict(all_labels)
    
    
    # data entries for each client
    unique_ids, unique_counts = np.unique(all_ids, return_counts=True)
    global_counts = 0
    for client_id, client_counts in zip(unique_ids, unique_counts):
        
        client_labels = all_labels[global_counts : global_counts + client_counts]
        client_data   = all_data  [global_counts : global_counts + client_counts]
        
        # local data imbalance and local normalization
        if not global_preprocessing:
            client_mean = client_data.mean(axis=(0,1))
            client_std  = client_data.std (axis=(0,1))
            client_data = (client_data - client_mean) / (client_std + 1e-6)
            weight_dict = get_weight_dict(client_labels)
            
        client = Client(client_id     = client_id     , 
                        client_labels = client_labels , 
                        client_data   = client_data   ,
                        weight_dict   = weight_dict   ,
                        batch_size    = batch_size    , 
                        global_model  = global_model  , 
                        learning_rate = learning_rate , 
                        l2_regular    = l2_regular    , 
                        client_epoch  = client_epoch  ,
                        reuse_optimizer  = reuse_optimizer  ,
                        train_test_split = train_test_split ,
                       )
                
        clients.append(client)
        global_counts += client_counts
            
    return clients

# %% [markdown]
# ## Global update

# %%
def federated_learning(global_epoch     = 500   ,
                       client_epoch     = 10    ,
                       update_C         = 0.1   ,
                       batch_size       = 4     ,
                       learning_rate    = 1e-5  ,
                       l2_regular       = 1e-1  ,
                       reuse_optimizer  = True  ,
                       train_test_split = 0.8   ,
                       global_init      = True ,
                       global_preprocessing = False,
                       known_client_data_size = True,
                      ):
    """ simulation of federated learning
    
    @ global_epoch    : number of rounds for global update
    @ client_epoch    : number of rounds for local  update (parameter E in paper)
    @ update_C        : proportion of clients that are updated in each global round (parameter C in paper)
    @ batch_size      : local batch size
    @ learning_rate   : local learning rate
    @ l2_regular      : local l2 regularization
    @ reuse_optimizer : whether the state of local optimizer is re-used 
    @ train_test_split: local train test split, any value outside (0, 1) means not doing split
    
    @ global_init           : whether all local models have the same initilization
    @ global_preprocessing  : whether data is normalized globally or locally
    @ known_client_data_size: whether the global center knows how much data each client has
    
    """
    
    # global model
    global_model = LSTM(batch_size = batch_size)
    
    # determine how many clients are updated per global round
    num_client        = len(np.unique(all_ids, return_counts=True)[0])
    num_update_client = min(max(math.ceil(update_C * num_client), 1), num_client) # number of clients to update per round
    print("total number of clients:", num_client, " number of clients to be updated in each global round:", num_update_client)
    print()
    
    clients = get_clients(batch_size       = batch_size    , 
                          learning_rate    = learning_rate , 
                          l2_regular       = l2_regular    , 
                          client_epoch     = client_epoch  ,
                          reuse_optimizer  = reuse_optimizer ,
                          train_test_split = train_test_split,
                          global_model     = global_model if global_init else None,
                          global_preprocessing = global_preprocessing
                         )
    
    # global test dataset and data loader
    if 0 < train_test_split < 1:
        test_datasets = [c.test_dataset for c in clients]
        global_test_dataset = torch.utils.data.ConcatDataset(test_datasets)
        global_test_loader  = torch.utils.data.DataLoader(global_test_dataset, batch_size = batch_size, shuffle = True, drop_last=True)
        
    # global update loop
    for epoch in notebook.tqdm(range(global_epoch)):
        client_ids     = np.random.choice(num_client, num_update_client, replace=False)
        client_weights = []
        client_params  = []
        client_train_losses  = []
        client_train_accus   = []
        client_train_f1s     = []
        client_test_losses   = []
        client_test_accus    = []
        client_test_f1s      = []
        
        # local update
        for client_id in client_ids:
            client = clients[client_id]
            client_weights.append(len(client.client_data) if known_client_data_size else 1.0)
            
            # local train
            loss, accu, f1 = client.local_train()
            client_params.append(client.client_model.state_dict())
            client_train_losses.append(loss)
            client_train_accus .append(accu)
            client_train_f1s   .append(f1)
            
            # local test
            loss, accu, f1 = client.local_test()
            client_test_losses.append(loss)
            client_test_accus .append(accu)
            client_test_f1s   .append(f1)
        
        # print
        avg_client_train_loss = weighted_avg(values = client_train_losses, weights = client_weights)
        avg_client_train_accu = weighted_avg(values = client_train_accus , weights = client_weights)
        avg_client_train_f1   = weighted_avg(values = client_train_f1s   , weights = client_weights)
        avg_client_test_loss  = weighted_avg(values = client_test_losses , weights = client_weights)
        avg_client_test_accu  = weighted_avg(values = client_test_accus  , weights = client_weights)
        avg_client_test_f1    = weighted_avg(values = client_test_f1s    , weights = client_weights)
        print("global epoch: {:02d}".format(epoch), " updating clients:", client_ids)
        print("avg client train loss: {:.4f}".format(avg_client_train_loss), " avg client train accu: {:.4f}".format(avg_client_train_accu), " avg client train f1: {:.4f}".format(avg_client_train_f1))
        print("avg client test  loss: {:.4f}".format(avg_client_test_loss ), " avg client test  accu: {:.4f}".format(avg_client_test_accu ), " avg client test  f1: {:.4f}".format(avg_client_test_f1 ))
        
        # add to tensorboard
        writer.add_scalar('global/train/avg_loss', avg_client_train_loss, epoch)
        writer.add_scalar('global/train/avg_accu', avg_client_train_accu, epoch)
        writer.add_scalar('global/train/avg_f1'  , avg_client_train_f1  , epoch)
        writer.add_scalar('global/test/avg_loss' , avg_client_test_loss , epoch)
        writer.add_scalar('global/test/avg_accu' , avg_client_test_accu , epoch)
        writer.add_scalar('global/test/avg_f1'   , avg_client_test_f1   , epoch)
        writer.flush()
        
        # global model aggregation
        client_params .append(global_model.state_dict())
        client_weights.append(len(all_data) if known_client_data_size else 1.0)
        new_global_params = weighted_avg_params(params = client_params, weights = client_weights)
        
        # update global model
        global_model.load_state_dict(new_global_params)
        
        # update local models
        for client in clients:
            client.client_model.load_state_dict(new_global_params)
            
        # global test
        global_model.to(device)
        global_model.eval()
        sum_batch_loss = 0
        sum_batch_len  = 0
        global_test_labels   = []
        global_test_predicts = []
        
        with torch.no_grad():
            for batch_id, (labels, weights, sequences) in enumerate(global_test_loader):
                sum_batch_len += len(labels)
                labels    = labels   .to(device)
                weights   = weights  .to(device)
                sequences = sequences.to(device)
                predicts  = global_model(sequences).view(-1)

                loss = F.binary_cross_entropy(predicts, labels, reduction = 'mean', weight = weights)
                sum_batch_loss += loss.item() * len(labels)

                predicts = predicts.round()
                global_test_labels  .append(labels)
                global_test_predicts.append(predicts)

        global_test_label   = torch.concatenate(global_test_labels  ).detach().to('cpu').numpy()
        global_test_predict = torch.concatenate(global_test_predicts).detach().to('cpu').numpy()
        global_test_loss    = sum_batch_loss / sum_batch_len
        global_test_accu    = accuracy_score(global_test_label, global_test_predict)
        global_test_f1      = f1_score      (global_test_label, global_test_predict, zero_division = 0)
        
        # print
        print("global test loss: {:.4f}".format(global_test_loss), " global test accu: {:.4f}".format(global_test_accu), " global test f1: {:.4f}".format(global_test_f1))
        print("global test predicts:", np.unique(global_test_predict, return_counts=True), "global test truth:", np.unique(global_test_label, return_counts=True))
        
        # add to tensorboard
        writer.add_scalar('global/test/global_loss', avg_client_train_loss, epoch)
        writer.add_scalar('global/test/global_accu', avg_client_train_accu, epoch)
        writer.add_scalar('global/test/global_f1'  , avg_client_train_f1  , epoch)
        
        print("======================================================================================================================================================================================================")
        
        global_model.to('cpu')

# %% [markdown]
# ## Run and plots

# %%
# %reload_ext tensorboard
# !rmdir /s /q runs
writer = SummaryWriter()
# %tensorboard --logdir runs

federated_learning(update_C     = 0.1,
                   client_epoch = 50, 
                   global_epoch = 1000,
                   
                   learning_rate   = 1e-5,
                   l2_regular      = 1e-1,
                   reuse_optimizer = True,
                   
                   global_init = True,
                   global_preprocessing = False,
                   known_client_data_size = True,
                  )
# Out:
# Reusing TensorBoard on port 6006 (pid 11308), started 4 days, 19:30:23 ago. (Use '!kill 11308' to kill it.)
#       <iframe id="tensorboard-frame-8b27a7775ab29ff4" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-8b27a7775ab29ff4");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
# C:\Software\Anaconda3\lib\site-packages\torch\nn\modules\rnn.py:67: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.5 and num_layers=1
#   warnings.warn("dropout option adds dropout after all but last "
# total number of clients: 15  number of clients to be updated in each global round: 2
#   0%|          | 0/1000 [00:00<?, ?it/s]
# global epoch: 00  updating clients: [1 6]
# avg client train loss: 0.4281  avg client train accu: 0.9067  avg client train f1: 0.1071
# avg client test  loss: 0.5120  avg client test  accu: 0.8558  avg client test  f1: 0.0000
# global test loss: 0.8273  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 01  updating clients: [2 4]
# avg client train loss: 0.7090  avg client train accu: 0.8563  avg client train f1: 0.2093
# avg client test  loss: 0.8678  avg client test  accu: 0.7802  avg client test  f1: 0.0000
# global test loss: 0.8232  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 02  updating clients: [ 4 12]
# avg client train loss: 1.0471  avg client train accu: 0.7524  avg client train f1: 0.1356
# avg client test  loss: 1.2171  avg client test  accu: 0.6265  avg client test  f1: 0.0000
# global test loss: 0.8335  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 03  updating clients: [13  6]
# avg client train loss: 0.4301  avg client train accu: 0.9106  avg client train f1: 0.2864
# avg client test  loss: 0.3152  avg client test  accu: 0.9641  avg client test  f1: 0.0000
# global test loss: 0.8320  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 04  updating clients: [ 0 10]
# avg client train loss: 1.0842  avg client train accu: 0.7331  avg client train f1: 0.0612
# avg client test  loss: 1.1829  avg client test  accu: 0.6897  avg client test  f1: 0.0000
# global test loss: 0.8360  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 05  updating clients: [ 1 13]
# avg client train loss: 0.9138  avg client train accu: 0.7960  avg client train f1: 0.1832
# avg client test  loss: 0.5744  avg client test  accu: 0.9427  avg client test  f1: 0.0000
# global test loss: 0.8331  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 06  updating clients: [ 2 12]
# avg client train loss: 0.8290  avg client train accu: 0.8105  avg client train f1: 0.2053
# avg client test  loss: 0.8672  avg client test  accu: 0.7522  avg client test  f1: 0.0000
# global test loss: 0.8307  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 07  updating clients: [10  6]
# avg client train loss: 0.5839  avg client train accu: 0.8601  avg client train f1: 0.1385
# avg client test  loss: 0.4358  avg client test  accu: 0.9375  avg client test  f1: 0.0000
# global test loss: 0.8242  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 08  updating clients: [13 12]
# avg client train loss: 1.0366  avg client train accu: 0.7568  avg client train f1: 0.2286
# avg client test  loss: 0.8701  avg client test  accu: 0.7897  avg client test  f1: 0.0000
# global test loss: 0.8235  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 09  updating clients: [ 8 10]
# avg client train loss: 0.6811  avg client train accu: 0.8374  avg client train f1: 0.1421
# avg client test  loss: 0.5310  avg client test  accu: 0.9046  avg client test  f1: 0.0000
# global test loss: 0.8304  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 10  updating clients: [10  8]
# avg client train loss: 0.6770  avg client train accu: 0.8385  avg client train f1: 0.2019
# avg client test  loss: 0.5309  avg client test  accu: 0.9046  avg client test  f1: 0.0000
# global test loss: 0.8317  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 11  updating clients: [4 1]
# avg client train loss: 0.9138  avg client train accu: 0.8144  avg client train f1: 0.2487
# avg client test  loss: 1.1459  avg client test  accu: 0.7016  avg client test  f1: 0.2042
# global test loss: 0.8321  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 12  updating clients: [ 2 11]
# avg client train loss: 0.2542  avg client train accu: 0.9659  avg client train f1: 0.2366
# avg client test  loss: 0.3181  avg client test  accu: 0.9375  avg client test  f1: 0.0000
# global test loss: 0.8333  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 13  updating clients: [ 2 14]
# avg client train loss: 0.7846  avg client train accu: 0.8316  avg client train f1: 0.3226
# avg client test  loss: 0.7923  avg client test  accu: 0.8434  avg client test  f1: 0.0000
# global test loss: 0.8349  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 14  updating clients: [ 7 10]
# avg client train loss: 1.4323  avg client train accu: 0.8530  avg client train f1: 0.0631
# avg client test  loss: 1.3332  avg client test  accu: 0.8969  avg client test  f1: 0.0000
# global test loss: 0.8313  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 15  updating clients: [1 2]
# avg client train loss: 0.6535  avg client train accu: 0.8821  avg client train f1: 0.3943
# avg client test  loss: 0.7664  avg client test  accu: 0.8259  avg client test  f1: 0.0000
# global test loss: 0.8297  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 16  updating clients: [ 0 10]
# avg client train loss: 1.0535  avg client train accu: 0.7448  avg client train f1: 0.1187
# avg client test  loss: 1.1427  avg client test  accu: 0.7204  avg client test  f1: 0.0000
# global test loss: 0.8195  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 17  updating clients: [ 4 14]
# avg client train loss: 0.9748  avg client train accu: 0.7915  avg client train f1: 0.2871
# avg client test  loss: 0.9556  avg client test  accu: 0.8125  avg client test  f1: 0.2500
# global test loss: 0.8247  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 18  updating clients: [ 3 13]
# avg client train loss: 1.0293  avg client train accu: 0.7532  avg client train f1: 0.2650
# avg client test  loss: 0.7418  avg client test  accu: 0.8722  avg client test  f1: 0.0000
# global test loss: 0.8309  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 19  updating clients: [2 5]
# avg client train loss: 0.5915  avg client train accu: 0.8990  avg client train f1: 0.3603
# avg client test  loss: 0.7833  avg client test  accu: 0.8114  avg client test  f1: 0.0000
# global test loss: 0.8305  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 20  updating clients: [3 6]
# avg client train loss: 0.5734  avg client train accu: 0.8534  avg client train f1: 0.2360
# avg client test  loss: 0.5646  avg client test  accu: 0.8921  avg client test  f1: 0.0000
# global test loss: 0.8241  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 21  updating clients: [ 0 10]
# avg client train loss: 1.0478  avg client train accu: 0.7498  avg client train f1: 0.1607
# avg client test  loss: 1.1514  avg client test  accu: 0.7204  avg client test  f1: 0.0000
# global test loss: 0.8234  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 22  updating clients: [7 3]
# avg client train loss: 1.4683  avg client train accu: 0.8550  avg client train f1: 0.1163
# avg client test  loss: 1.3249  avg client test  accu: 0.9190  avg client test  f1: 0.0000
# global test loss: 0.8276  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 23  updating clients: [ 6 13]
# avg client train loss: 0.4043  avg client train accu: 0.9308  avg client train f1: 0.3482
# avg client test  loss: 0.1894  avg client test  accu: 1.0000  avg client test  f1: 0.0000
# global test loss: 0.8214  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 24  updating clients: [10  1]
# avg client train loss: 0.9935  avg client train accu: 0.7689  avg client train f1: 0.2070
# avg client test  loss: 0.9999  avg client test  accu: 0.7788  avg client test  f1: 0.0000
# global test loss: 0.8297  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 25  updating clients: [1 3]
# avg client train loss: 1.0534  avg client train accu: 0.7463  avg client train f1: 0.2351
# avg client test  loss: 1.1683  avg client test  accu: 0.6941  avg client test  f1: 0.0000
# global test loss: 0.8300  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 26  updating clients: [14  4]
# avg client train loss: 0.9501  avg client train accu: 0.8115  avg client train f1: 0.3822
# avg client test  loss: 0.9230  avg client test  accu: 0.8750  avg client test  f1: 0.4286
# global test loss: 0.8282  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 27  updating clients: [12 11]
# avg client train loss: 0.5715  avg client train accu: 0.8671  avg client train f1: 0.1204
# avg client test  loss: 0.7391  avg client test  accu: 0.7522  avg client test  f1: 0.0000
# global test loss: 0.8298  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 28  updating clients: [1 3]
# avg client train loss: 1.0516  avg client train accu: 0.7479  avg client train f1: 0.2484
# avg client test  loss: 0.9641  avg client test  accu: 0.7961  avg client test  f1: 0.0000
# global test loss: 0.8298  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 29  updating clients: [12 14]
# avg client train loss: 1.0752  avg client train accu: 0.7610  avg client train f1: 0.3291
# avg client test  loss: 1.0553  avg client test  accu: 0.7515  avg client test  f1: 0.1395
# global test loss: 0.8286  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 30  updating clients: [0 2]
# avg client train loss: 0.7335  avg client train accu: 0.8601  avg client train f1: 0.4160
# avg client test  loss: 1.0878  avg client test  accu: 0.7188  avg client test  f1: 0.0000
# global test loss: 0.8266  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 31  updating clients: [13  2]
# avg client train loss: 0.6072  avg client train accu: 0.9120  avg client train f1: 0.6052
# avg client test  loss: 0.5024  avg client test  accu: 0.9292  avg client test  f1: 0.0000
# global test loss: 0.8303  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 32  updating clients: [6 9]
# avg client train loss: 0.2030  avg client train accu: 0.9687  avg client train f1: 0.3779
# avg client test  loss: 0.1867  avg client test  accu: 0.9688  avg client test  f1: 0.0000
# global test loss: 0.8293  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 33  updating clients: [ 0 10]
# avg client train loss: 1.0144  avg client train accu: 0.7718  avg client train f1: 0.2684
# avg client test  loss: 1.1861  avg client test  accu: 0.7204  avg client test  f1: 0.0000
# global test loss: 0.8324  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 34  updating clients: [5 6]
# avg client train loss: 0.3853  avg client train accu: 0.9325  avg client train f1: 0.2996
# avg client test  loss: 0.5076  avg client test  accu: 0.8750  avg client test  f1: 0.0000
# global test loss: 0.8307  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 35  updating clients: [ 7 13]
# avg client train loss: 1.1885  avg client train accu: 0.9374  avg client train f1: 0.2663
# avg client test  loss: 0.8987  avg client test  accu: 1.0000  avg client test  f1: 0.0000
# global test loss: 0.8190  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 36  updating clients: [9 1]
# avg client train loss: 0.5303  avg client train accu: 0.9010  avg client train f1: 0.3741
# avg client test  loss: 0.5750  avg client test  accu: 0.8558  avg client test  f1: 0.0000
# global test loss: 0.8286  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 37  updating clients: [1 6]
# avg client train loss: 0.3919  avg client train accu: 0.9262  avg client train f1: 0.2725
# avg client test  loss: 0.4280  avg client test  accu: 0.9135  avg client test  f1: 0.0000
# global test loss: 0.8291  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 38  updating clients: [5 1]
# avg client train loss: 0.7494  avg client train accu: 0.8612  avg client train f1: 0.3481
# avg client test  loss: 0.8856  avg client test  accu: 0.7981  avg client test  f1: 0.0000
# global test loss: 0.8193  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 39  updating clients: [8 0]
# avg client train loss: 0.6203  avg client train accu: 0.8716  avg client train f1: 0.3553
# avg client test  loss: 0.8711  avg client test  accu: 0.7812  avg client test  f1: 0.0000
# global test loss: 0.8210  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 40  updating clients: [10  0]
# avg client train loss: 1.0005  avg client train accu: 0.7743  avg client train f1: 0.2809
# avg client test  loss: 1.1973  avg client test  accu: 0.7204  avg client test  f1: 0.0000
# global test loss: 0.8155  global test accu: 0.8443  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([206,  38], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 41  updating clients: [ 1 14]
# avg client train loss: 0.9520  avg client train accu: 0.8136  avg client train f1: 0.4259
# avg client test  loss: 0.9945  avg client test  accu: 0.7782  avg client test  f1: 0.0000
# global test loss: 0.8213  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 42  updating clients: [12 14]
# avg client train loss: 1.0353  avg client train accu: 0.7875  avg client train f1: 0.4233
# avg client test  loss: 1.0811  avg client test  accu: 0.7500  avg client test  f1: 0.2929
# global test loss: 0.8232  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 43  updating clients: [3 7]
# avg client train loss: 1.2683  avg client train accu: 0.8746  avg client train f1: 0.1839
# avg client test  loss: 1.1359  avg client test  accu: 0.8786  avg client test  f1: 0.0000
# global test loss: 0.8218  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 44  updating clients: [ 6 10]
# avg client train loss: 0.5449  avg client train accu: 0.8851  avg client train f1: 0.4171
# avg client test  loss: 0.5990  avg client test  accu: 0.8750  avg client test  f1: 0.0000
# global test loss: 0.8301  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 45  updating clients: [13  1]
# avg client train loss: 0.8025  avg client train accu: 0.8665  avg client train f1: 0.5391
# avg client test  loss: 0.6347  avg client test  accu: 0.8854  avg client test  f1: 0.0000
# global test loss: 0.8303  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 46  updating clients: [10  8]
# avg client train loss: 0.6317  avg client train accu: 0.8660  avg client train f1: 0.4096
# avg client test  loss: 0.5214  avg client test  accu: 0.9046  avg client test  f1: 0.0000
# global test loss: 0.8228  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 47  updating clients: [10 11]
# avg client train loss: 0.5101  avg client train accu: 0.9029  avg client train f1: 0.2401
# avg client test  loss: 0.5952  avg client test  accu: 0.8739  avg client test  f1: 0.0000
# global test loss: 0.8243  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 48  updating clients: [4 0]
# avg client train loss: 0.8692  avg client train accu: 0.8518  avg client train f1: 0.5290
# avg client test  loss: 1.2485  avg client test  accu: 0.7515  avg client test  f1: 0.3794
# global test loss: 0.8322  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 49  updating clients: [7 9]
# avg client train loss: 0.7394  avg client train accu: 0.9746  avg client train f1: 0.2851
# avg client test  loss: 0.5888  avg client test  accu: 1.0000  avg client test  f1: 0.0000
# global test loss: 0.8250  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 50  updating clients: [10  9]
# avg client train loss: 0.6341  avg client train accu: 0.8753  avg client train f1: 0.5099
# avg client test  loss: 0.5252  avg client test  accu: 0.9062  avg client test  f1: 0.0000
# global test loss: 0.8293  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 51  updating clients: [12  5]
# avg client train loss: 0.8176  avg client train accu: 0.8590  avg client train f1: 0.5291
# avg client test  loss: 1.0128  avg client test  accu: 0.8428  avg client test  f1: 0.6306
# global test loss: 0.8198  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 52  updating clients: [8 9]
# avg client train loss: 0.2627  avg client train accu: 0.9573  avg client train f1: 0.5839
# avg client test  loss: 0.1061  avg client test  accu: 1.0000  avg client test  f1: 0.0000
# global test loss: 0.8312  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 53  updating clients: [12  9]
# avg client train loss: 0.6319  avg client train accu: 0.8934  avg client train f1: 0.6058
# avg client test  loss: 0.5824  avg client test  accu: 0.9090  avg client test  f1: 0.3883
# global test loss: 0.8214  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 54  updating clients: [ 3 10]
# avg client train loss: 1.0321  avg client train accu: 0.7862  avg client train f1: 0.4459
# avg client test  loss: 0.9597  avg client test  accu: 0.8216  avg client test  f1: 0.2906
# global test loss: 0.8313  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 55  updating clients: [14 11]
# avg client train loss: 0.5005  avg client train accu: 0.9167  avg client train f1: 0.2894
# avg client test  loss: 0.6125  avg client test  accu: 0.8427  avg client test  f1: 0.0000
# global test loss: 0.8310  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 56  updating clients: [5 1]
# avg client train loss: 0.6893  avg client train accu: 0.8926  avg client train f1: 0.5522
# avg client test  loss: 1.0065  avg client test  accu: 0.7788  avg client test  f1: 0.3077
# global test loss: 0.8243  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 57  updating clients: [ 5 11]
# avg client train loss: 0.3075  avg client train accu: 0.9645  avg client train f1: 0.3501
# avg client test  loss: 0.5946  avg client test  accu: 0.8739  avg client test  f1: 0.2035
# global test loss: 0.8249  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 58  updating clients: [10  3]
# avg client train loss: 1.0225  avg client train accu: 0.7926  avg client train f1: 0.4769
# avg client test  loss: 0.8912  avg client test  accu: 0.8568  avg client test  f1: 0.2906
# global test loss: 0.8313  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 59  updating clients: [4 1]
# avg client train loss: 0.7678  avg client train accu: 0.8898  avg client train f1: 0.6451
# avg client test  loss: 1.0716  avg client test  accu: 0.8266  avg client test  f1: 0.6532
# global test loss: 0.8305  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 60  updating clients: [7 2]
# avg client train loss: 0.7510  avg client train accu: 0.9769  avg client train f1: 0.3857
# avg client test  loss: 0.8097  avg client test  accu: 0.8985  avg client test  f1: 0.0000
# global test loss: 0.8208  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 61  updating clients: [ 8 10]
# avg client train loss: 0.5984  avg client train accu: 0.8892  avg client train f1: 0.5066
# avg client test  loss: 0.5206  avg client test  accu: 0.9046  avg client test  f1: 0.0000
# global test loss: 0.8334  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 62  updating clients: [2 1]
# avg client train loss: 0.5543  avg client train accu: 0.9304  avg client train f1: 0.7024
# avg client test  loss: 0.7948  avg client test  accu: 0.8371  avg client test  f1: 0.2619
# global test loss: 0.8304  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 63  updating clients: [11  8]
# avg client train loss: 0.1297  avg client train accu: 0.9765  avg client train f1: 0.2699
# avg client test  loss: 0.1846  avg client test  accu: 0.9688  avg client test  f1: 0.0000
# global test loss: 0.8184  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 64  updating clients: [12  2]
# avg client train loss: 0.6888  avg client train accu: 0.9010  avg client train f1: 0.6952
# avg client test  loss: 0.7983  avg client test  accu: 0.8434  avg client test  f1: 0.4235
# global test loss: 0.8230  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 65  updating clients: [10  8]
# avg client train loss: 0.5999  avg client train accu: 0.8867  avg client train f1: 0.5160
# avg client test  loss: 0.5138  avg client test  accu: 0.9046  avg client test  f1: 0.0000
# global test loss: 0.8241  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 66  updating clients: [9 4]
# avg client train loss: 0.4868  avg client train accu: 0.9351  avg client train f1: 0.6895
# avg client test  loss: 0.4672  avg client test  accu: 0.9379  avg client test  f1: 0.3729
# global test loss: 0.8311  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 67  updating clients: [9 2]
# avg client train loss: 0.3234  avg client train accu: 0.9598  avg client train f1: 0.7202
# avg client test  loss: 0.3736  avg client test  accu: 0.9079  avg client test  f1: 0.0000
# global test loss: 0.8240  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 68  updating clients: [ 1 14]
# avg client train loss: 0.8674  avg client train accu: 0.8557  avg client train f1: 0.6215
# avg client test  loss: 1.0247  avg client test  accu: 0.6734  avg client test  f1: 0.0000
# global test loss: 0.8190  global test accu: 0.8402  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 69  updating clients: [0 4]
# avg client train loss: 0.7827  avg client train accu: 0.8844  avg client train f1: 0.6702
# avg client test  loss: 1.2216  avg client test  accu: 0.7522  avg client test  f1: 0.4336
# global test loss: 0.8312  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 70  updating clients: [4 6]
# avg client train loss: 0.3650  avg client train accu: 0.9563  avg client train f1: 0.6529
# avg client test  loss: 0.5184  avg client test  accu: 0.9064  avg client test  f1: 0.3314
# global test loss: 0.8389  global test accu: 0.8361  global test f1: 0.0000
# global test predicts: (array([0.], dtype=float32), array([244], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 71  updating clients: [14 10]
# avg client train loss: 0.9205  avg client train accu: 0.8425  avg client train f1: 0.6290
# ...
# avg client test  loss: 0.8953  avg client test  accu: 0.7142  avg client test  f1: 0.4247
# global test loss: 0.9340  global test accu: 0.7992  global test f1: 0.1695
# global test predicts: (array([0., 1.], dtype=float32), array([225,  19], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 977  updating clients: [4 9]
# avg client train loss: 0.1812  avg client train accu: 0.9830  avg client train f1: 0.9402
# avg client test  loss: 0.3081  avg client test  accu: 0.9068  avg client test  f1: 0.3314
# global test loss: 0.9440  global test accu: 0.8156  global test f1: 0.2105
# global test predicts: (array([0., 1.], dtype=float32), array([227,  17], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 978  updating clients: [6 1]
# avg client train loss: 0.1563  avg client train accu: 0.9752  avg client train f1: 0.7901
# avg client test  loss: 1.2336  avg client test  accu: 0.8654  avg client test  f1: 0.1923
# global test loss: 0.9232  global test accu: 0.8115  global test f1: 0.1481
# global test predicts: (array([0., 1.], dtype=float32), array([229,  15], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 979  updating clients: [9 0]
# avg client train loss: 0.2510  avg client train accu: 0.9627  avg client train f1: 0.9096
# avg client test  loss: 1.2830  avg client test  accu: 0.7850  avg client test  f1: 0.1092
# global test loss: 0.9546  global test accu: 0.8074  global test f1: 0.1132
# global test predicts: (array([0., 1.], dtype=float32), array([231,  13], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 980  updating clients: [ 5 11]
# avg client train loss: 0.1487  avg client train accu: 0.9815  avg client train f1: 0.4446
# avg client test  loss: 0.8091  avg client test  accu: 0.9057  avg client test  f1: 0.3391
# global test loss: 0.9534  global test accu: 0.8033  global test f1: 0.1111
# global test predicts: (array([0., 1.], dtype=float32), array([230,  14], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 981  updating clients: [12 14]
# avg client train loss: 0.4574  avg client train accu: 0.9414  avg client train f1: 0.8971
# avg client test  loss: 1.2000  avg client test  accu: 0.7471  avg client test  f1: 0.4185
# global test loss: 0.9505  global test accu: 0.8156  global test f1: 0.1818
# global test predicts: (array([0., 1.], dtype=float32), array([229,  15], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 982  updating clients: [13  0]
# avg client train loss: 0.3391  avg client train accu: 0.9565  avg client train f1: 0.9142
# avg client test  loss: 1.8696  avg client test  accu: 0.6806  avg client test  f1: 0.1133
# global test loss: 0.9351  global test accu: 0.8033  global test f1: 0.1724
# global test predicts: (array([0., 1.], dtype=float32), array([225,  19], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 983  updating clients: [12  4]
# avg client train loss: 0.3335  avg client train accu: 0.9740  avg client train f1: 0.9481
# avg client test  loss: 0.6016  avg client test  accu: 0.8430  avg client test  f1: 0.7684
# global test loss: 0.9456  global test accu: 0.8074  global test f1: 0.1754
# global test predicts: (array([0., 1.], dtype=float32), array([226,  18], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([205,  39], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 984  updating clients: [13  1]
# avg client train loss: 0.2872  avg client train accu: 0.9735  avg client train f1: 0.9407
# avg client test  loss: 1.1584  avg client test  accu: 0.8403  avg client test  f1: 0.2292
# global test loss: 0.9498  global test accu: 0.7951  global test f1: 0.1379
# global test predicts: (array([0., 1.], dtype=float32), array([226,  18], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 985  updating clients: [ 2 13]
# avg client train loss: 0.1909  avg client train accu: 0.9795  avg client train f1: 0.9319
# avg client test  loss: 0.7463  avg client test  accu: 0.7514  avg client test  f1: 0.0000
# global test loss: 0.9410  global test accu: 0.7828  global test f1: 0.1311
# global test predicts: (array([0., 1.], dtype=float32), array([223,  21], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 986  updating clients: [13  0]
# avg client train loss: 0.3151  avg client train accu: 0.9622  avg client train f1: 0.9244
# avg client test  loss: 1.9104  avg client test  accu: 0.7160  avg client test  f1: 0.1259
# global test loss: 0.9469  global test accu: 0.7787  global test f1: 0.1290
# global test predicts: (array([0., 1.], dtype=float32), array([222,  22], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 987  updating clients: [1 0]
# avg client train loss: 0.3532  avg client train accu: 0.9575  avg client train f1: 0.9113
# avg client test  loss: 2.4846  avg client test  accu: 0.6362  avg client test  f1: 0.3313
# global test loss: 0.9695  global test accu: 0.7746  global test f1: 0.1270
# global test predicts: (array([0., 1.], dtype=float32), array([221,  23], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 988  updating clients: [11  9]
# avg client train loss: 0.0546  avg client train accu: 0.9894  avg client train f1: 0.4666
# avg client test  loss: 0.2723  avg client test  accu: 0.9693  avg client test  f1: 0.0000
# global test loss: 0.9606  global test accu: 0.7705  global test f1: 0.1250
# global test predicts: (array([0., 1.], dtype=float32), array([220,  24], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 989  updating clients: [1 6]
# avg client train loss: 0.1520  avg client train accu: 0.9782  avg client train f1: 0.7919
# avg client test  loss: 0.9191  avg client test  accu: 0.9135  avg client test  f1: 0.2564
# global test loss: 0.9600  global test accu: 0.7746  global test f1: 0.0984
# global test predicts: (array([0., 1.], dtype=float32), array([223,  21], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 990  updating clients: [3 8]
# avg client train loss: 0.3498  avg client train accu: 0.9211  avg client train f1: 0.7174
# avg client test  loss: 0.4099  avg client test  accu: 0.8889  avg client test  f1: 0.2540
# global test loss: 0.9466  global test accu: 0.7828  global test f1: 0.1587
# global test predicts: (array([0., 1.], dtype=float32), array([221,  23], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 991  updating clients: [ 0 13]
# avg client train loss: 0.3117  avg client train accu: 0.9622  avg client train f1: 0.9236
# avg client test  loss: 1.9557  avg client test  accu: 0.6806  avg client test  f1: 0.1133
# global test loss: 0.9541  global test accu: 0.7623  global test f1: 0.1212
# global test predicts: (array([0., 1.], dtype=float32), array([218,  26], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 992  updating clients: [ 1 13]
# avg client train loss: 0.2556  avg client train accu: 0.9844  avg client train f1: 0.9635
# avg client test  loss: 0.4501  avg client test  accu: 0.8976  avg client test  f1: 0.0000
# global test loss: 0.9445  global test accu: 0.7582  global test f1: 0.1194
# global test predicts: (array([0., 1.], dtype=float32), array([217,  27], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 993  updating clients: [10  9]
# avg client train loss: 0.3228  avg client train accu: 0.9407  avg client train f1: 0.8591
# avg client test  loss: 0.5245  avg client test  accu: 0.7812  avg client test  f1: 0.0000
# global test loss: 0.9530  global test accu: 0.7664  global test f1: 0.0952
# global test predicts: (array([0., 1.], dtype=float32), array([221,  23], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 994  updating clients: [10  1]
# avg client train loss: 0.4342  avg client train accu: 0.9431  avg client train f1: 0.8980
# avg client test  loss: 1.0709  avg client test  accu: 0.7212  avg client test  f1: 0.2564
# global test loss: 0.9581  global test accu: 0.7541  global test f1: 0.0909
# global test predicts: (array([0., 1.], dtype=float32), array([218,  26], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 995  updating clients: [10  5]
# avg client train loss: 0.3728  avg client train accu: 0.9497  avg client train f1: 0.8927
# avg client test  loss: 1.0961  avg client test  accu: 0.7188  avg client test  f1: 0.3333
# global test loss: 0.9514  global test accu: 0.7664  global test f1: 0.1231
# global test predicts: (array([0., 1.], dtype=float32), array([219,  25], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 996  updating clients: [11 13]
# avg client train loss: 0.0891  avg client train accu: 0.9960  avg client train f1: 0.4269
# avg client test  loss: 0.3300  avg client test  accu: 0.9646  avg client test  f1: 0.0000
# global test loss: 0.9465  global test accu: 0.7664  global test f1: 0.1231
# global test predicts: (array([0., 1.], dtype=float32), array([219,  25], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 997  updating clients: [ 1 12]
# avg client train loss: 0.3666  avg client train accu: 0.9728  avg client train f1: 0.9502
# avg client test  loss: 0.6851  avg client test  accu: 0.8750  avg client test  f1: 0.5155
# global test loss: 0.9431  global test accu: 0.7623  global test f1: 0.1212
# global test predicts: (array([0., 1.], dtype=float32), array([218,  26], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 998  updating clients: [10 12]
# avg client train loss: 0.4268  avg client train accu: 0.9606  avg client train f1: 0.9314
# avg client test  loss: 0.8030  avg client test  accu: 0.7463  avg client test  f1: 0.4247
# global test loss: 0.9402  global test accu: 0.7705  global test f1: 0.1515
# global test predicts: (array([0., 1.], dtype=float32), array([218,  26], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
# global epoch: 999  updating clients: [9 3]
# avg client train loss: 0.3137  avg client train accu: 0.9630  avg client train f1: 0.9205
# avg client test  loss: 0.3042  avg client test  accu: 0.9637  avg client test  f1: 0.3487
# global test loss: 0.9388  global test accu: 0.7787  global test f1: 0.2059
# global test predicts: (array([0., 1.], dtype=float32), array([216,  28], dtype=int64)) global test truth: (array([0., 1.], dtype=float32), array([204,  40], dtype=int64))
# ======================================================================================================================================================================================================
